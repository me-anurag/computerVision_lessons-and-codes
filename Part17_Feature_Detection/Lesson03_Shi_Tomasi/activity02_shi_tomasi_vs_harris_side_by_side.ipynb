# %% [markdown]
# # Activity 02 — Shi-Tomasi vs Harris Side by Side
#
# Detect corners using Shi-Tomasi (goodFeaturesToTrack with useHarrisDetector=False) and Harris (useHarrisDetector=True) on the same image with the same count limit. Draw both sets and compare locations and distribution.
