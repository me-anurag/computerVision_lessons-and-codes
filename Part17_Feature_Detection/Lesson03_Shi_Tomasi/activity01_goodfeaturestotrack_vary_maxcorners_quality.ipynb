# %% [markdown]
# # Activity 01 — goodFeaturesToTrack: Vary maxCorners and qualityLevel
#
# Apply cv2.goodFeaturesToTrack with different maxCorners (50, 100, 500) and qualityLevel (0.001, 0.01, 0.1) values. Display a grid of results showing how these parameters control corner density and quality.
