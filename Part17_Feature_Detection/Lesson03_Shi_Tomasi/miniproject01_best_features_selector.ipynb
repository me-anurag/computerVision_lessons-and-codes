# %% [markdown]
# # Mini Project 01 — Best Features Selector
#
# Build a feature quality display tool that detects the top 50 Shi-Tomasi corners, ranks them by quality score, and draws each point with a circle whose size or color reflects its relative quality score.
