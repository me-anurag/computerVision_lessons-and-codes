# %% [markdown]
# # Activity 01 — SIFT Keypoints with Scale and Orientation
#
# Detect SIFT keypoints and draw them using cv2.drawKeypoints with the DRAW_RICH_KEYPOINTS flag to show scale (circle size) and orientation (line from center). Observe how SIFT captures multi-scale structure.
