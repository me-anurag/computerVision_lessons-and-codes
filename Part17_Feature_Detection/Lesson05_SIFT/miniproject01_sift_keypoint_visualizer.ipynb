# %% [markdown]
# # Mini Project 01 — SIFT Keypoint Visualizer
#
# Build a SIFT visualization tool that draws each keypoint with its scale circle and orientation arrow. Color keypoints by their octave (scale level) to show the multi-scale detection pyramid.
