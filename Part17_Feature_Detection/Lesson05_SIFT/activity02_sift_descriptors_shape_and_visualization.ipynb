# %% [markdown]
# # Activity 02 — SIFT Descriptors: Shape and Visualization
#
# Compute SIFT descriptors for an image. Print the descriptor array shape. Visualize a single 128-dimensional descriptor as a bar chart to understand what the descriptor encodes.
