# %% [markdown]
# # Activity 02 — FAST with NonMaxSuppression On vs Off
#
# Detect FAST keypoints with nonmaxSuppression=True and nonmaxSuppression=False on the same image. Display both results and compare the number of keypoints and their spatial distribution.
