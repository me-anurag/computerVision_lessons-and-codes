# %% [markdown]
# # Mini Project 01 — Real-Time Keypoint Counter on Webcam
#
# Build a live webcam tool that runs FAST detection on every frame and displays the keypoints as green dots along with the live keypoint count and current FPS as text overlay.
