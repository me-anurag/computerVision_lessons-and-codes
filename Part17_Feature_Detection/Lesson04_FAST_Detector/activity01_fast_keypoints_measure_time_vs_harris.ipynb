# %% [markdown]
# # Activity 01 — FAST Keypoints and Speed Comparison vs Harris
#
# Detect keypoints using the FAST detector and measure detection time. Compare with Harris corner detection time on the same image. Print both times and the number of keypoints detected by each.
