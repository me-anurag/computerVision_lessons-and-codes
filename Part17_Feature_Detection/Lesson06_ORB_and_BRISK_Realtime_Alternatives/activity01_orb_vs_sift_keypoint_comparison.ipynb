# %% [markdown]
# # Activity 01 — ORB vs SIFT Keypoint Comparison
#
# Detect keypoints using ORB and SIFT on the same image. Display results side by side. Print the number of keypoints found by each, their descriptor sizes (32 bytes vs 128 floats), and note the computational difference.
