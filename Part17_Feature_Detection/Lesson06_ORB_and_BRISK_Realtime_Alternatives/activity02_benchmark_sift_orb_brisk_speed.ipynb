# %% [markdown]
# # Activity 02 — Benchmark SIFT, ORB, and BRISK Speed
#
# Run SIFT, ORB, and BRISK detection 50 times each on the same image and measure average execution time. Print a comparison table of mean time, number of keypoints, and descriptor size for each.
