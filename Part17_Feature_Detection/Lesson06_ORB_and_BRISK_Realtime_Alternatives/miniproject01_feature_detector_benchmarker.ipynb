# %% [markdown]
# # Mini Project 01 — Feature Detector Benchmarker
#
# Build a benchmarking tool that runs SIFT, ORB, and BRISK on a set of test images and produces a summary report table comparing speed (ms), keypoint count, descriptor size, and a quality note for each.
