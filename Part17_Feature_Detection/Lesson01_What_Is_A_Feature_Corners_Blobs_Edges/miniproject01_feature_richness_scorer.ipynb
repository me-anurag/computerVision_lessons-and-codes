# %% [markdown]
# # Mini Project 01 — Feature Richness Scorer
#
# Build a tool that estimates how many trackable features an image has. Use Shi-Tomasi to count corners and report a richness score. Compare scores across a set of images (textured, smooth, busy, plain).
