# %% [markdown]
# # Activity 01 — Identify Good Features in Real Images
#
# Load several real-world images (indoor scene, textured surface, plain wall). Manually annotate which regions contain good features (corners, blobs) and which are featureless. Discuss what makes a region trackable.
