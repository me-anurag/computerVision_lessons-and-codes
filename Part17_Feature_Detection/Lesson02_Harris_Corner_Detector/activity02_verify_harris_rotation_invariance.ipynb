# %% [markdown]
# # Activity 02 — Verify Harris Rotation Invariance
#
# Detect Harris corners on an image, rotate the image by 30° and 60°, detect corners again on rotated versions. Overlay all detections and verify that the same corners are detected regardless of rotation.
