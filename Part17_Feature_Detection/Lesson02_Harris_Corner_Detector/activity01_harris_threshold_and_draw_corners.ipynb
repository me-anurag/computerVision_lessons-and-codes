# %% [markdown]
# # Activity 01 — Harris Corner Detection, Thresholding, and Drawing
#
# Apply cv2.cornerHarris to a grayscale image, threshold the response map to keep strong corners, dilate for visibility, and draw the corner locations on the original image.
