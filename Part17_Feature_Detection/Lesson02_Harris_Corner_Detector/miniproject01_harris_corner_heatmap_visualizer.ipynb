# %% [markdown]
# # Mini Project 01 — Harris Corner Heatmap Visualizer
#
# Build a visualizer that computes the Harris response map and overlays it as a semi-transparent heatmap (using a colormap) on the original image, showing where strong corners exist.
