# %% [markdown]
# # Activity 01 — Save and Load PyTorch Model: Full Model vs Weights Only
#
# Save a trained PyTorch model in two ways: full model with torch.save(model) and weights only with torch.save(model.state_dict()). Load both and run inference. Compare file sizes and loading behavior.
