# %% [markdown]
# # Mini Project 01 — Model Registry with JSON Index
#
# Build a local model registry. When saving a trained model, automatically log its metadata (model name, architecture, training date, validation accuracy, dataset, config) to a JSON index file. Include functions to list and retrieve models by name.
