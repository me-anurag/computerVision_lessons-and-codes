# %% [markdown]
# # Mini Project 01 — Vision API: FastAPI Server for Object Detection
#
# Build a production-style vision API using FastAPI. The server accepts image uploads at a /predict endpoint, runs a YOLO detection model, and returns structured JSON with all detections. Include input validation and error handling.
