# %% [markdown]
# # Activity 01 — Wrap YOLO in a FastAPI Endpoint and Test with POST Request
#
# Build a FastAPI server with a /detect endpoint that accepts an image file upload. Load a YOLO model at startup, run inference on each received image, and return a JSON response with detected class names, confidence scores, and bounding boxes.
