# %% [markdown]
# # Activity 01 — Export to ONNX, Run with OpenCV DNN, Verify Output Matches
#
# Export a trained PyTorch model to ONNX. Load the ONNX model in OpenCV DNN. Run the same test image through both. Compare outputs numerically (mean absolute difference) to verify export correctness.
