# %% [markdown]
# # Mini Project 01 — Model Converter: PyTorch to ONNX with Verification
#
# Build an automated model conversion tool. Take any PyTorch model, export it to ONNX with dynamic input shapes, run a correctness verification step comparing PyTorch vs ONNX outputs, and print a pass/fail verification report.
