# %% [markdown]
# # Activity 01 — Log Inference Latency, Confidence Scores, and Class Counts to CSV
#
# Add logging to a detection pipeline. For each inference request, log: timestamp, inference latency (ms), detected class names, confidence scores, and total detection count to a CSV file.
