# %% [markdown]
# # Mini Project 01 — Monitoring Dashboard Using Gradio
#
# Build a live monitoring dashboard using Gradio. Read the inference log CSV file and display: a latency over time line chart, a class detection frequency bar chart, and a confidence score distribution histogram — all updating in real time.
