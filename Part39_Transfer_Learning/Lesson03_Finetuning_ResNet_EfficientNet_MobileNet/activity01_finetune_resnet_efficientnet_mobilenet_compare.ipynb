# %% [markdown]
# # Activity 01 — Fine-Tune ResNet, EfficientNet, MobileNet on Same Dataset
#
# Fine-tune ResNet-18, EfficientNet-B0, and MobileNet-V2 on the same small dataset for the same number of epochs. Compare final validation accuracy and training time for each architecture.
