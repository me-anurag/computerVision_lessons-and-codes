# %% [markdown]
# # Mini Project 01 — Custom 5-Class Image Classifier
#
# Build a custom image classifier. Collect or curate a 5-class dataset (at least 100 images per class), fine-tune EfficientNet-B0 using transfer learning, and target above 85% validation accuracy.
