# %% [markdown]
# # Activity 01 — Freeze ResNet, Replace Head, Count Trainable Parameters
#
# Load a pretrained ResNet-50. Freeze all layers by setting requires_grad=False. Replace the final fully connected layer with a new head for a custom number of classes. Count and print frozen vs trainable parameters.
