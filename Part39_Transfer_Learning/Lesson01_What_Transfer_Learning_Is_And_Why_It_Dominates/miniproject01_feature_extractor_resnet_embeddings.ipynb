# %% [markdown]
# # Mini Project 01 — Feature Extractor Using Pretrained ResNet
#
# Build a feature extraction tool using a frozen pretrained ResNet-50. Pass a set of images through the network up to the penultimate layer and save the 2048-dimensional embeddings as a NumPy array for downstream use.
