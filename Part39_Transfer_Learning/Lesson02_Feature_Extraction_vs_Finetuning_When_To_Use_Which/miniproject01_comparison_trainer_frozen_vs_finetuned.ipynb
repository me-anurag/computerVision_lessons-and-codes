# %% [markdown]
# # Mini Project 01 — Comparison Trainer: Frozen vs Fine-Tuned Backbone
#
# Build a systematic comparison trainer that trains a ResNet-18 in both modes for 10 epochs each on the same dataset. Plot side-by-side accuracy curves and print the final test accuracy for each.
