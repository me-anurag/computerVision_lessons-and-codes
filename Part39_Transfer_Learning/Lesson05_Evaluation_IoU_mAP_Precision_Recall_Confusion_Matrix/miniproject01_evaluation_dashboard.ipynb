# %% [markdown]
# # Mini Project 01 — Evaluation Dashboard
#
# Build a model evaluation dashboard. Given model predictions and ground truth labels, plot: a confusion matrix heatmap, a precision-recall curve per class, and display the overall mAP and per-class AP scores.
