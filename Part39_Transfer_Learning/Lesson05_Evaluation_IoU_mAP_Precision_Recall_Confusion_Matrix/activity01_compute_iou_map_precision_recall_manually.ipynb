# %% [markdown]
# # Activity 01 — Compute IoU, mAP, Precision, and Recall Manually
#
# Manually implement IoU calculation between two boxes. Compute precision and recall from a small detection result set. Calculate AP by integrating the precision-recall curve. Verify results against torchmetrics.
