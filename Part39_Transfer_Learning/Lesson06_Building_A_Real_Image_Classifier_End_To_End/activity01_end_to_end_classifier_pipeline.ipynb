# %% [markdown]
# # Activity 01 — End-to-End Classifier Pipeline
#
# Build the complete pipeline in a single notebook: load a dataset, apply augmentations, fine-tune a pretrained model, evaluate on a test set, export to ONNX, and run an inference test using OpenCV DNN.
