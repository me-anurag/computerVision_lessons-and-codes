# %% [markdown]
# # Mini Project 01 — Full Classifier: Dataset → Train → Evaluate → Deploy
#
# Build a deployable image classifier from scratch. Collect data, annotate, augment, train with transfer learning, evaluate comprehensively, export to ONNX, and write an inference script that runs on new images from the command line.
