# %% [markdown]
# # Mini Project 01 — Augmentation Pipeline for a Detection Dataset
#
# Build an Albumentations augmentation pipeline for an object detection dataset. Apply spatial transforms (flip, rotate, crop) and color transforms while correctly transforming the bounding box coordinates. Visualize augmented samples with boxes.
