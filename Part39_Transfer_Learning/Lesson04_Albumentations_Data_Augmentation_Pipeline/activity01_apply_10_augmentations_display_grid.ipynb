# %% [markdown]
# # Activity 01 — Apply 10 Augmentations and Display in a Grid
#
# Apply 10 different Albumentations transforms to the same image: HorizontalFlip, RandomBrightnessContrast, Rotate, GaussNoise, ElasticTransform, GridDistortion, CLAHE, HueSaturationValue, CoarseDropout, Blur. Display all in a 2x5 grid.
