# %% [markdown]
# # Mini Project 01 — Edge Strength Map
#
# Build a tool that computes the gradient magnitude using Sobel operators, normalizes it to 0-255, and applies a colormap (cv2.COLORMAP_JET) to produce a visually informative edge strength heatmap.
