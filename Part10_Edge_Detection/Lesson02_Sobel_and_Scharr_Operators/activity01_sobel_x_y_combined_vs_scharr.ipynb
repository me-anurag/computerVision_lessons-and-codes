# %% [markdown]
# # Activity 01 — Sobel X, Y, Combined vs Scharr
#
# Apply Sobel in X direction, Y direction, and combined (magnitude). Repeat with the Scharr operator. Display all results side by side and compare edge sharpness, especially on thin features.
