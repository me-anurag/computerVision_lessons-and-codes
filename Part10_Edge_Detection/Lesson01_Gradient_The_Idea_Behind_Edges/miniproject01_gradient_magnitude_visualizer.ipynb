# %% [markdown]
# # Mini Project 01 — Gradient Magnitude Visualizer
#
# Build a visualizer that computes Gx and Gy using Sobel operators, then computes the gradient magnitude and direction. Display Gx, Gy, magnitude, and a color-coded direction map as a 2x2 grid.
