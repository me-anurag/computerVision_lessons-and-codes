# %% [markdown]
# # Activity 01 — Compute Gradient Manually with NumPy vs Sobel
#
# Compute the image gradient manually using np.diff along rows and columns. Compare the result with cv2.Sobel output by overlaying both edge maps and computing pixel-wise differences.
