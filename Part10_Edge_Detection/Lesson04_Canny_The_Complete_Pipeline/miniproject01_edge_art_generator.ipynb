# %% [markdown]
# # Mini Project 01 — Edge Art Generator
#
# Build a pencil sketch effect generator. Apply Canny edge detection to a photo, invert the result to get black lines on white background, and optionally blend it with a grayscale version of the original for a realistic sketch look.
