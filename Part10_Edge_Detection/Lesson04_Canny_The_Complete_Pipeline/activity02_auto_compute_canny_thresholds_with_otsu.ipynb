# %% [markdown]
# # Activity 02 — Auto-Compute Canny Thresholds Using Otsu
#
# Use Otsu's method to automatically determine a good threshold value from the image. Set Canny's high threshold to the Otsu value and low threshold to half of it. Compare with manually tuned thresholds.
