# %% [markdown]
# # Activity 01 — Tune Canny Low and High Thresholds Manually
#
# Apply cv2.Canny with different threshold pairs on several images. Display results in a grid and observe how thresholds control which edges are kept or discarded.
