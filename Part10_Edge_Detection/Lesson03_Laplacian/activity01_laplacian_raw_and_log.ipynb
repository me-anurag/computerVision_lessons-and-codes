# %% [markdown]
# # Activity 01 — Raw Laplacian vs Laplacian of Gaussian (LoG)
#
# Apply the Laplacian operator directly to an image and observe double-edge artifacts and noise sensitivity. Then apply Gaussian blur first (LoG) and compare — observe how pre-blurring reduces noise in the edge response.
