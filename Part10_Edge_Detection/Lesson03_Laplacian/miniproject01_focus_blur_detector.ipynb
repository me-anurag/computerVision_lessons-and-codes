# %% [markdown]
# # Mini Project 01 — Focus/Blur Detector
#
# Build a sharpness scorer using Laplacian variance. Load a set of images (some sharp, some blurry), compute the variance of the Laplacian for each, and classify them as sharp or blurry based on a threshold.
