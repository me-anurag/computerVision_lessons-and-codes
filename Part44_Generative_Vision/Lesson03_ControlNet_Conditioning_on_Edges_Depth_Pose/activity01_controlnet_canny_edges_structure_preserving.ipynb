# %% [markdown]
# # Activity 01 — ControlNet with Canny Edges for Structure-Preserving Generation
#
# Extract Canny edges from a photo. Use ControlNet with the edge condition to generate a new image that preserves the structural layout of the original while applying a different style based on a text prompt.
