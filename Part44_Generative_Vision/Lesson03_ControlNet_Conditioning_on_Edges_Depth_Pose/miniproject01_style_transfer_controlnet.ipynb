# %% [markdown]
# # Mini Project 01 — Style Transfer Tool Using ControlNet
#
# Build a structure-preserving style transfer tool. Take any photo, extract its Canny or depth map, use ControlNet to regenerate the scene in a specified art style while preserving composition.
