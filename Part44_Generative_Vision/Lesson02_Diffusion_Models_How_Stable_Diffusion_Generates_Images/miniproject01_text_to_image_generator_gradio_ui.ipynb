# %% [markdown]
# # Mini Project 01 — Text-to-Image Generator with Gradio UI
#
# Build a text-to-image generation app with a Gradio UI. The user types a text prompt, selects number of steps and guidance scale via sliders, clicks generate, and the generated image is displayed in the interface.
