# %% [markdown]
# # Activity 01 — Stable Diffusion: Generate Images from Text Prompts
#
# Use the HuggingFace diffusers library to run Stable Diffusion locally or via API. Generate 4 images from different text prompts. Vary the number of inference steps and guidance scale and observe the quality changes.
