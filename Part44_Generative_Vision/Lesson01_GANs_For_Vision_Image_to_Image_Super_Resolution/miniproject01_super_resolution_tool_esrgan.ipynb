# %% [markdown]
# # Mini Project 01 — Super Resolution Tool Using ESRGAN
#
# Build a super resolution tool. Take any low-resolution image, run it through ESRGAN for 4x upscaling, and display a before/after comparison with PSNR and SSIM quality metrics printed for evaluation.
