# %% [markdown]
# # Activity 01 — ESRGAN 4x Upscaling vs Bicubic Interpolation
#
# Load a pretrained ESRGAN model. Upscale a low-resolution image by 4x using ESRGAN. Also upscale the same image using bicubic interpolation. Display all three (original, bicubic, ESRGAN) side by side and compare sharpness.
