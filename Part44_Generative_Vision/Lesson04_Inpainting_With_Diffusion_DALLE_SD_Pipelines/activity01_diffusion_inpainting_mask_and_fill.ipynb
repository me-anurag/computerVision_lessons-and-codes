# %% [markdown]
# # Activity 01 — Diffusion Inpainting: Draw a Mask and Fill a Region
#
# Draw a binary mask over an unwanted object in an image. Use a Stable Diffusion inpainting pipeline to fill the masked region with plausible content guided by a text prompt. Display original, mask, and inpainted result.
