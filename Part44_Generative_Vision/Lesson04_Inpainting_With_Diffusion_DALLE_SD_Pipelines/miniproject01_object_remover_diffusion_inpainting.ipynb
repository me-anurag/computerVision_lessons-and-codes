# %% [markdown]
# # Mini Project 01 — Object Remover Using Diffusion Inpainting
#
# Build an object removal tool. The user draws over an unwanted object using a simple mask drawing UI. The tool feeds the image and mask into a diffusion inpainting model and fills the region naturally.
