# %% [markdown]
# # Activity 01 — Project a 3D Point to 2D Using the Pinhole Equations
#
# Manually implement the pinhole camera projection equations. Given a 3D world point and a camera matrix (fx, fy, cx, cy), compute the 2D pixel coordinates. Verify against cv2.projectPoints output.
