# %% [markdown]
# # Mini Project 01 — 3D to 2D Point Projector
#
# Build a projection tool that takes a list of 3D world points and a camera intrinsic matrix as inputs and projects all points onto the image plane. Display the projected points on a blank canvas or real image.
