# %% [markdown]
# # Mini Project 01 — Calibration Quality Checker
#
# Build a calibration quality assessment tool that computes and visualizes per-image reprojection errors as a bar chart. Flag images with error above a threshold as poor-quality calibration inputs.
