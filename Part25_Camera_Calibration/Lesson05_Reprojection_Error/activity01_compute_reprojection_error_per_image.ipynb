# %% [markdown]
# # Activity 01 — Compute Per-Image Reprojection Error
#
# After calibration, compute the reprojection error for each calibration image by projecting 3D object points back to 2D using the estimated camera parameters. Print per-image error and the mean error.
