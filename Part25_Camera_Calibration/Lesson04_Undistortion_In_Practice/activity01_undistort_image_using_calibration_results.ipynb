# %% [markdown]
# # Activity 01 — Undistort an Image Using Calibration Results
#
# Load saved calibration results (camera matrix + distortion coefficients). Apply cv2.undistort to a distorted image. Display original and undistorted side by side and observe lens distortion correction.
