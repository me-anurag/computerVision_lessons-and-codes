# %% [markdown]
# # Mini Project 01 — Lens Corrector
#
# Build a lens correction tool that takes any image and a calibration .npz file as inputs, applies cv2.undistort, and saves the corrected image. Include a side-by-side comparison visualization.
