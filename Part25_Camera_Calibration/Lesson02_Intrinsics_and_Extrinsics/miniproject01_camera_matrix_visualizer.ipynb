# %% [markdown]
# # Mini Project 01 — Camera Matrix Visualizer
#
# Build a visual explanation tool showing what each camera matrix parameter does. Use diagrams to illustrate how changing focal length zooms the view and how changing principal point shifts the image center.
