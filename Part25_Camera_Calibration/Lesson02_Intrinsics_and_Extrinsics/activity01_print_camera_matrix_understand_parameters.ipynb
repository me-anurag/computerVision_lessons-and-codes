# %% [markdown]
# # Activity 01 — Print Camera Matrix and Understand fx, fy, cx, cy
#
# Load or define a camera matrix K. Print fx, fy, cx, cy values and explain what each one controls: focal length in pixels (fx, fy) and principal point offset (cx, cy). Discuss what happens when each changes.
