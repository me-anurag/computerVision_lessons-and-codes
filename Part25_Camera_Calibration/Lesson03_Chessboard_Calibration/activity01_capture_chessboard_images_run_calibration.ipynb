# %% [markdown]
# # Activity 01 — Capture Chessboard Images and Run Calibration
#
# Capture 15+ images of a printed chessboard from different angles. Detect corners with cv2.findChessboardCorners, refine to subpixel, collect object/image point pairs, and run cv2.calibrateCamera. Print the results.
