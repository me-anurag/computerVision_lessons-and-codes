# %% [markdown]
# # Mini Project 01 — Full Calibration Pipeline
#
# Build an end-to-end calibration pipeline: open webcam, auto-detect the chessboard in each frame, collect enough valid samples, run calibration, save the camera matrix and distortion coefficients to a .npz file.
