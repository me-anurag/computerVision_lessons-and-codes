# %% [markdown]
# # Mini Project 01 — Fisheye Unwrapper
#
# Build a fisheye-to-flat conversion tool. Given a fisheye distorted image and a fisheye calibration file, apply the undistortion model to produce a flat perspective view and save the result.
