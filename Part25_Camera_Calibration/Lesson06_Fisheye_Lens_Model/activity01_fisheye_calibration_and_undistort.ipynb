# %% [markdown]
# # Activity 01 — Fisheye Camera Calibration and Undistortion
#
# Use cv2.fisheye.calibrate with chessboard images from a wide-angle fisheye camera. Apply cv2.fisheye.undistortImage to correct the barrel distortion and display the corrected flat-perspective output.
