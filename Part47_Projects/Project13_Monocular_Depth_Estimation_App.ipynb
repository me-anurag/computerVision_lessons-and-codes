# %% [markdown]
# # Project 13 — Monocular Depth Estimation App
#
# Build a depth estimation app using MiDaS. Load a pretrained MiDaS model, run inference on webcam frames or images, apply a colormap to the relative depth output, and display the depth map alongside the original image. Add a depth-based background blur effect.
