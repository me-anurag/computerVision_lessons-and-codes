# %% [markdown]
# # Project 04 — Real-Time Face Blur
#
# Build a privacy protection tool that runs on a live webcam feed. Use a DNN face detector to find all faces in each frame. Apply Gaussian blur to each detected face region and display the anonymized output in real time.
