# %% [markdown]
# # Project 02 — Lane Detection
#
# Build a lane detection pipeline for road videos. Apply perspective warp to get a bird's-eye view of the road, use edge detection and Hough line transform to detect lane lines, filter by angle to keep only lane markings, and overlay the detected lanes back on the original frame in real time.
