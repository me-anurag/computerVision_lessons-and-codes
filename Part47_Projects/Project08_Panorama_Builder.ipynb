# %% [markdown]
# # Project 08 — Panorama Builder
#
# Build a panorama stitching tool. Take a folder of overlapping images, detect and match features between adjacent images using SIFT and FLANN, compute homographies, warp and blend images onto a shared canvas, and save the final wide-angle panorama.
