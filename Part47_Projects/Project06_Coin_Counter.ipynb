# %% [markdown]
# # Project 06 — Coin Counter
#
# Build a coin counting tool. Use morphological closing and Hough Circle Transform to detect circular coins in an image. Filter detections by expected radius range, draw circles around each detected coin, and display the total coin count.
