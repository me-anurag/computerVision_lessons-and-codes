# %% [markdown]
# # Project 07 — AR Marker Overlay
#
# Build an augmented reality marker overlay tool. Detect ArUco markers in a video or webcam feed, estimate their pose using solvePnP, and overlay a 2D or 3D image/pattern onto the marker surface with correct perspective using homography.
