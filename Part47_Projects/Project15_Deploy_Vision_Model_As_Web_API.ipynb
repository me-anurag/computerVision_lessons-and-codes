# %% [markdown]
# # Project 15 — Deploy a Vision Model as a Web API
#
# Build a production-ready vision model deployment. Train or load a YOLO model, export it to ONNX, build a FastAPI server with a /predict endpoint that accepts image uploads and returns detection results as structured JSON. Add a simple Gradio frontend for browser-based testing and an inference log for monitoring.
