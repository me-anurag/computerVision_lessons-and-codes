# %% [markdown]
# # Project 01 — Document Scanner
#
# Build a complete document scanning app. Detect the document edges using edge detection and contour finding, compute a perspective transform from the 4 detected corners, warp to a flat A4 view, apply adaptive thresholding for a clean black-and-white output, and save the final scanned document.
