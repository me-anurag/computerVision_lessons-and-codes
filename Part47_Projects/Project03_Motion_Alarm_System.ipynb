# %% [markdown]
# # Project 03 — Motion Alarm System
#
# Build a real-time motion alarm system using a webcam. Apply background subtraction (MOG2), threshold and clean the foreground mask, compute total motion area, and trigger a visual alert (red border) and console alarm when motion exceeds a configurable threshold.
