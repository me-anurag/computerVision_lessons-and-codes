# %% [markdown]
# # Project 05 — Number Plate Recognition
#
# Build a license plate reader. Detect plate candidates using edge detection and contour filtering, apply perspective correction to flatten the plate, preprocess the plate image (threshold, denoise), and run Tesseract OCR to extract the plate number text.
