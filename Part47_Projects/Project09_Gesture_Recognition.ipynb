# %% [markdown]
# # Project 09 — Gesture Recognition
#
# Build a real-time hand gesture recognizer using a webcam. Segment the hand using skin color HSV masking, find the hand contour, compute convexity defects, count the number of raised fingers, and display the gesture name (zero through five fingers) as a live overlay.
