# %% [markdown]
# # Project 10 — Visual Inspection Pipeline
#
# Build an automated visual quality inspection system. Load a reference defect-free image, compare incoming test images using absolute difference and thresholding, locate defect regions using contour detection, classify defects by area, and generate a text defect report with locations.
