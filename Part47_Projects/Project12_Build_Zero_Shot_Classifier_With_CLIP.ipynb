# %% [markdown]
# # Project 12 — Zero-Shot Image Classifier with CLIP
#
# Build a zero-shot image classification system using CLIP. Define a list of class name text prompts. For each input image, encode the image and all prompts using CLIP, compute cosine similarities, and assign the class with the highest similarity score — no training required.
