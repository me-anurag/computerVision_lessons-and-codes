# %% [markdown]
# # Project 14 — Real-Time Segmentation with SAM
#
# Build an interactive segmentation tool using SAM. Display a live webcam feed or static image. When the user clicks on any object, pass the click coordinates as a point prompt to SAM, compute the segmentation mask instantly, and overlay it with a colored highlight on the image.
