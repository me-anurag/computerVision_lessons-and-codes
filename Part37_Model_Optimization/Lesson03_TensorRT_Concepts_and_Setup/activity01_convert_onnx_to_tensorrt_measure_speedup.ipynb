# %% [markdown]
# # Activity 01 — Convert ONNX to TensorRT Engine and Measure Speedup
#
# Convert an ONNX model to a TensorRT engine (requires GPU). Run inference using TensorRT and compare the inference time against the ONNX baseline to measure the GPU optimization speedup.
