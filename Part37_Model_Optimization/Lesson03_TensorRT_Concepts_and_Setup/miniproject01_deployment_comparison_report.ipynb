# %% [markdown]
# # Mini Project 01 — Deployment Comparison Report
#
# Build a comprehensive deployment benchmarking report. Run the same vision model across all available backends (PyTorch CPU, PyTorch GPU, OpenCV DNN CPU, OpenVINO, TensorRT if available) and produce a formatted comparison table.
