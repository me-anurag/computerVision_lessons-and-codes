# %% [markdown]
# # Activity 01 — Convert ONNX to OpenVINO IR and Run Inference
#
# Convert an ONNX model to OpenVINO IR format using the Model Optimizer. Load it with the OpenVINO runtime, run inference on a test image, and measure execution time compared to PyTorch and OpenCV DNN.
