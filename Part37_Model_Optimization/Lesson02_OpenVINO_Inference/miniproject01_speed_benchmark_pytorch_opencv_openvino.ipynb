# %% [markdown]
# # Mini Project 01 — Speed Benchmark: PyTorch vs OpenCV DNN vs OpenVINO
#
# Build a benchmarking tool that runs the same model on the same inputs using three backends: native PyTorch, OpenCV DNN, and OpenVINO. Report mean inference time for each as a comparison table.
