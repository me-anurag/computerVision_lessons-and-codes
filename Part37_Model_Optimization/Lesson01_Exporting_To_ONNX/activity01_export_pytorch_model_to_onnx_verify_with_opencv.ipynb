# %% [markdown]
# # Activity 01 — Export a PyTorch Model to ONNX and Verify with OpenCV
#
# Take a simple pretrained PyTorch classification model, export it to ONNX using torch.onnx.export. Load the ONNX model in OpenCV DNN, run inference, and verify the output matches the PyTorch output.
