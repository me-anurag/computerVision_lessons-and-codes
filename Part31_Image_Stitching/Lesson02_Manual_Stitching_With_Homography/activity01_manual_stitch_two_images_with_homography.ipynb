# %% [markdown]
# # Activity 01 — Manual Stitch Two Images Using Homography
#
# Detect SIFT features in two overlapping images, match them, compute a homography, warp one image onto the canvas of the other, and blend the overlap region using weighted averaging to reduce the seam.
