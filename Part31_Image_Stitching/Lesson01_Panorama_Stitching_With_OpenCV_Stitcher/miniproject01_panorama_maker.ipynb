# %% [markdown]
# # Mini Project 01 — Panorama Maker
#
# Build a panorama maker that takes a folder of overlapping images as input, uses the OpenCV Stitcher pipeline to stitch them all together, and saves the final wide-angle panorama image.
