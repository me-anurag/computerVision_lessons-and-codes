# %% [markdown]
# # Activity 01 — Stitch 3 Overlapping Photos Using OpenCV Stitcher
#
# Take 3 overlapping photos of a wide scene. Pass them to cv2.Stitcher_create().stitch(). Display the resulting panorama and note any seam or exposure artifacts.
