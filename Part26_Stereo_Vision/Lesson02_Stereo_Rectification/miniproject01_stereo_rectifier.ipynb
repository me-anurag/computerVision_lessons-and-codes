# %% [markdown]
# # Mini Project 01 — Stereo Rectifier
#
# Build a stereo rectification tool that takes a raw stereo image pair and calibration data, applies stereo rectification, and outputs side-by-side rectified images ready for disparity computation.
