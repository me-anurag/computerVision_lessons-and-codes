# %% [markdown]
# # Activity 01 — Rectify a Stereo Pair and Verify Row Alignment
#
# Apply cv2.stereoRectify to a stereo camera pair. Remap both images using the rectification maps. Draw horizontal lines across both rectified images to verify that corresponding features now lie on the same row.
