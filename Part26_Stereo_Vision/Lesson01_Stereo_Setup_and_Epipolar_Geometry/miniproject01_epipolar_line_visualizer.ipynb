# %% [markdown]
# # Mini Project 01 — Epipolar Line Visualizer
#
# Build an interactive epipolar visualizer. When the user clicks a point on the left image, compute and draw its epipolar line on the right image using the fundamental matrix.
