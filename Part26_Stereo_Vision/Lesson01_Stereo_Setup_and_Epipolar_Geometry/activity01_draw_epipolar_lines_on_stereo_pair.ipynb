# %% [markdown]
# # Activity 01 — Draw Epipolar Lines on a Stereo Image Pair
#
# Load a stereo image pair. Select several point correspondences manually or using feature matching. Compute the fundamental matrix and draw the corresponding epipolar lines on both images.
