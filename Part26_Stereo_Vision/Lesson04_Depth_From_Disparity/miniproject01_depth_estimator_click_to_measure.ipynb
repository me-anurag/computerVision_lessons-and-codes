# %% [markdown]
# # Mini Project 01 — Click-to-Measure Depth Estimator
#
# Build a depth measurement tool using a stereo camera setup. Display the left image and when the user clicks on a point, compute and print the estimated real-world distance in cm using the disparity at that point.
