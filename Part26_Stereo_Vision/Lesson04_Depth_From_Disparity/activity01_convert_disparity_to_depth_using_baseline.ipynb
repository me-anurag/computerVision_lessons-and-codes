# %% [markdown]
# # Activity 01 — Convert Disparity to Depth Using Focal Length and Baseline
#
# Given a disparity map, focal length (in pixels), and stereo baseline (in cm), compute the depth map using depth = (focal_length * baseline) / disparity. Print depth values at several image locations.
