# %% [markdown]
# # Activity 01 — StereoBM vs StereoSGBM Disparity Map Comparison
#
# Compute disparity maps using both cv2.StereoBM and cv2.StereoSGBM on the same rectified stereo pair. Display both colorized disparity maps side by side and compare detail quality and noise level.
