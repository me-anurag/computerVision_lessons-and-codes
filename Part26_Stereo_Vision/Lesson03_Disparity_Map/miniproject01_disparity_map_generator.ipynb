# %% [markdown]
# # Mini Project 01 — Disparity Map Generator
#
# Build a disparity map tool that takes a rectified stereo pair, computes StereoSGBM disparity, normalizes and applies a colormap (COLORMAP_JET), and saves the colorized disparity map.
