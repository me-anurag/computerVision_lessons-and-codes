# %% [markdown]
# # Activity 01 — Box Filter with Increasing Kernel Sizes
#
# Apply cv2.blur with kernel sizes 3x3, 7x7, 15x15, and 31x31 to the same image. Display all results in a grid and observe how increasing kernel size increases blur strength.
