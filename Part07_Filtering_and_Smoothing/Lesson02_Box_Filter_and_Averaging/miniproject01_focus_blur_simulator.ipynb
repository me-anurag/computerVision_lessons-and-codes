# %% [markdown]
# # Mini Project 01 — Focus Blur Simulator
#
# Simulate a shallow depth-of-field effect: define a foreground mask region manually, apply box blur only to the background while keeping the foreground sharp, and blend both regions together.
