# %% [markdown]
# # Activity 01 — Box Blur vs Gaussian Blur Edge Comparison
#
# Apply box blur and Gaussian blur at the same kernel size to an image. Crop a region near a sharp edge in both results and compare how each method handles edge transitions.
