# %% [markdown]
# # Mini Project 01 — Portrait Mode Simulator
#
# Build a portrait mode effect: manually mask the subject (foreground), apply strong Gaussian blur to the background, and composite both layers to simulate a camera bokeh effect.
