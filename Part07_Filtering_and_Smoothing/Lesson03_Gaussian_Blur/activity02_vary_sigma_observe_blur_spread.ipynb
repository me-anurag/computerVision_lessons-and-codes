# %% [markdown]
# # Activity 02 — Vary Sigma and Observe Blur Spread
#
# Apply Gaussian blur with sigmaX values of 1, 3, 5, 10, and 20 using a fixed kernel size. Display all results and describe how increasing sigma widens the blur spread.
