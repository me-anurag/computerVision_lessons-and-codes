# %% [markdown]
# # Activity 02 — Apply Identity, Edge, and Emboss Kernels
#
# Define and apply three custom kernels: an identity kernel (no change), an edge detection kernel, and an emboss kernel. Display all results and explain what each kernel does mathematically.
