# %% [markdown]
# # Activity 01 — Manually Apply Average Kernel with filter2D
#
# Build a 3x3 averaging kernel manually as a NumPy array and apply it using cv2.filter2D. Verify the result matches cv2.blur output by computing the absolute difference.
