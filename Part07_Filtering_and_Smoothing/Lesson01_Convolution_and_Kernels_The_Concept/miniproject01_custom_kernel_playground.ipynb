# %% [markdown]
# # Mini Project 01 — Custom Kernel Playground
#
# Build an interactive tool with a 3x3 grid of trackbars representing kernel values. Apply the kernel in real time using cv2.filter2D and display the live result as the user edits kernel values.
