# %% [markdown]
# # Mini Project 01 — Noise Cleaner
#
# Build a noise cleaning tool specifically for salt-and-pepper noise. Detect noise pixels using thresholding, apply median blur with an appropriate kernel size, and compare the cleaned result against the noisy input.
