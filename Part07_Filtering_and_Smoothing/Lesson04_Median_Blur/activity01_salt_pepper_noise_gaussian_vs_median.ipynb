# %% [markdown]
# # Activity 01 — Salt-and-Pepper Noise: Gaussian vs Median Blur
#
# Add salt-and-pepper noise programmatically to a clean image. Apply Gaussian blur and median blur with the same kernel size. Compare how well each removes noise while preserving edges.
