# %% [markdown]
# # Activity 02 — Tune d, sigmaColor, and sigmaSpace Parameters
#
# Experiment with bilateral filter parameters: vary d (5, 9, 15), sigmaColor (25, 75, 150), and sigmaSpace (25, 75, 150) independently. Display a grid of results to understand each parameter's role.
