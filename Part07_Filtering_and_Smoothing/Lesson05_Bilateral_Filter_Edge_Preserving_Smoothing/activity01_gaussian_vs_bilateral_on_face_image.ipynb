# %% [markdown]
# # Activity 01 — Gaussian vs Bilateral on a Face Image
#
# Apply Gaussian blur and bilateral filter with comparable smoothing strength to a face portrait. Zoom into eye and skin regions to compare how bilateral filter preserves edges while Gaussian blurs them.
