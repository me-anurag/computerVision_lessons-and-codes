# %% [markdown]
# # Mini Project 01 — Cartoon Effect
#
# Build a cartoon effect by combining bilateral filtering (smooth skin-like regions) with edge detection (draw black outlines). Blend the smoothed image with the edge mask to produce a cartoon-style output.
