# %% [markdown]
# # Activity 01 — Subsample Dense Flow and Draw Arrow Grid
#
# Take the dense optical flow result, subsample it at a regular grid spacing (e.g. every 16 pixels), and draw an arrow at each grid point showing the local flow direction and magnitude.
