# %% [markdown]
# # Mini Project 01 — Crowd Flow Analyzer
#
# Build a crowd flow visualizer using dense optical flow on a crowd video. Draw a grid of arrows showing the dominant movement direction in each region, with arrow length proportional to movement speed.
