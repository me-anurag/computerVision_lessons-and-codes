# %% [markdown]
# # Activity 01 — Dense Optical Flow Visualized as HSV Image
#
# Compute cv2.calcOpticalFlowFarneback between two frames. Map the flow magnitude to the HSV value channel and the flow angle to the hue channel. Convert to BGR and display the resulting color-coded flow field.
