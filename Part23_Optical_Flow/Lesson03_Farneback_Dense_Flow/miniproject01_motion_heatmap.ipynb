# %% [markdown]
# # Mini Project 01 — Motion Heatmap
#
# Build a motion heatmap tool using dense optical flow. Accumulate the flow magnitude over multiple frames and display a heatmap showing which regions of the video have the most movement over time.
