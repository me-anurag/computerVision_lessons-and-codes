# %% [markdown]
# # Activity 01 — Track Shi-Tomasi Corners Across Frames with Lucas-Kanade
#
# Detect Shi-Tomasi corners on the first frame, then use cv2.calcOpticalFlowPyrLK to track them across subsequent frames. Draw the tracked points and lines showing their movement on each frame.
