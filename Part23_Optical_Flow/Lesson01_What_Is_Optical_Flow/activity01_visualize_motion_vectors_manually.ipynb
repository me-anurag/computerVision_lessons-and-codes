# %% [markdown]
# # Activity 01 — Visualize Motion Vectors Manually on a Frame
#
# Take two consecutive frames from a video. Manually draw arrows on a few points showing estimated pixel movement direction and magnitude to build intuition for what optical flow represents before computing it.
