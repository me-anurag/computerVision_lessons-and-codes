# %% [markdown]
# # Mini Project 01 — Optical Flow Concept Diagram
#
# Build a visual explanation diagram showing two frames side by side with arrows connecting corresponding pixels. Label key concepts: displacement vector, frame t, frame t+1, and motion direction.
