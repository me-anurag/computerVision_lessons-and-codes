# %% [markdown]
# # Mini Project 01 — Background Remover Using GrabCut
#
# Build a background removal tool using GrabCut. The user defines a bounding rectangle around the subject, the tool segments the foreground, and outputs the subject on a clean white background.
