# %% [markdown]
# # Activity 01 — GrabCut with Rectangle Initialization then Stroke Refinement
#
# Apply cv2.grabCut using a manually defined rectangle to initialize foreground/background. Then refine the result by painting foreground and background strokes and running additional GrabCut iterations.
