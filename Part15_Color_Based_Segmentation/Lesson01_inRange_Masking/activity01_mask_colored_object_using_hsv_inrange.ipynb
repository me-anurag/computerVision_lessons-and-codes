# %% [markdown]
# # Activity 01 — Mask a Colored Object Using HSV inRange
#
# Convert an image to HSV, define lower and upper HSV bounds for a specific color (e.g. red ball or green object), apply cv2.inRange to create a binary mask, and use it to isolate the colored object.
