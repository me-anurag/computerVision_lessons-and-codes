# %% [markdown]
# # Mini Project 01 — Color Object Isolator
#
# Build a color isolation tool. Using HSV thresholding with cv2.inRange, show only the pixels matching a target color while converting everything else to grayscale — creating a selective color effect.
