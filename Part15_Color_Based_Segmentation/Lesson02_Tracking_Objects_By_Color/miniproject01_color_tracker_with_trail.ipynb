# %% [markdown]
# # Mini Project 01 — Color Tracker with Motion Trail
#
# Build a color tracking tool that follows a colored object across frames and draws a fading trail showing the path the object has traveled over the last N frames.
