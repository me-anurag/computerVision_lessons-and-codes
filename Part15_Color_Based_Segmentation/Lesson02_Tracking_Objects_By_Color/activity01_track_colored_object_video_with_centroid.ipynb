# %% [markdown]
# # Activity 01 — Track a Colored Object in Video Using Centroid
#
# Apply HSV inRange masking on each frame of a video or webcam feed to isolate a colored object. Find its contour, compute the centroid, and draw a circle at the centroid position on each frame.
