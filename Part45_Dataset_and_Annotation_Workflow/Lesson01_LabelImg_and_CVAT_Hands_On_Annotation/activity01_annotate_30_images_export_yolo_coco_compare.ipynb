# %% [markdown]
# # Activity 01 — Annotate 30 Images in Both LabelImg and CVAT, Compare Export Formats
#
# Annotate 30 images using both LabelImg and CVAT. Export from each tool in YOLO format and COCO format. Compare the resulting file structures and confirm that annotations are consistent across both tools.
