# %% [markdown]
# # Mini Project 01 — Annotation Validator
#
# Build a validation script for YOLO-format annotations. Check that every image file has a matching .txt label file, that no label files are empty, that all coordinates are normalized (0-1), and report any violations found.
