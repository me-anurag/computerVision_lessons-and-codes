# %% [markdown]
# # Activity 01 — Upload Dataset to Roboflow, Apply Augmentations, Export
#
# Upload a raw annotated dataset to Roboflow. Apply 3 augmentation techniques (flip, brightness, crop). Export the augmented dataset in YOLO format and YOLOv8 format. Compare the exported folder structures.
