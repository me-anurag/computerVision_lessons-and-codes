# %% [markdown]
# # Mini Project 01 — Roboflow-Powered Dataset Pipeline
#
# Build a complete Roboflow workflow. Upload raw images, apply augmentations to 3x the dataset size, download the ready-to-train dataset via the Roboflow API, and verify the downloaded dataset structure and label quality.
