# %% [markdown]
# # Mini Project 01 — Dataset Analyzer
#
# Build a dataset analysis tool that scans a dataset folder, counts images and labels per class, computes the train/val/test split ratios, plots the class distribution as a bar chart, and flags classes with fewer than a specified minimum sample count.
