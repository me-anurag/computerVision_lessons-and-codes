# %% [markdown]
# # Activity 01 — Measure Class Distribution and Oversample Minority Classes
#
# Analyze a dataset's class distribution by counting samples per class. Identify minority classes. Apply random oversampling (duplicate minority samples) or undersampling (remove majority samples) to balance the distribution.
