# %% [markdown]
# # Mini Project 01 — Dataset Version Manager
#
# Build a dataset version management tool. Track dataset versions in a local JSON manifest file storing: version number, creation date, number of images per split, annotation format, and a changelog entry. Support listing and comparing versions.
