# %% [markdown]
# # Activity 01 — Create Dataset v1 and v2 with Different Annotation Strategies
#
# Create two versions of the same dataset: v1 with bounding box annotations and v2 with updated/corrected annotations. Store version metadata (date, annotator, changes) in a JSON file alongside each version.
