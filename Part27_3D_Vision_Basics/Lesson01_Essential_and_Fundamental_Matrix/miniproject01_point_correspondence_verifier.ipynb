# %% [markdown]
# # Mini Project 01 — Point Correspondence Verifier
#
# Build a tool that computes the fundamental matrix from matched keypoints and draws epipolar lines for each matched pair on both images, visually verifying that each point lies on its corresponding epipolar line.
