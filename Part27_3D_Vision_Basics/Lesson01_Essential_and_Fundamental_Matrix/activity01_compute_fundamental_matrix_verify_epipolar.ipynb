# %% [markdown]
# # Activity 01 — Compute Fundamental Matrix and Verify Epipolar Constraint
#
# Match keypoints between two views of a scene. Compute the fundamental matrix using cv2.findFundamentalMat with RANSAC. Verify the epipolar constraint (x'^T F x = 0) for matched point pairs.
