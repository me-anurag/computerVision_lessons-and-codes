# %% [markdown]
# # Activity 01 — SfM Pipeline: Detect → Match → Compute F → Triangulate
#
# Walk through the full Structure from Motion pipeline step by step on two images: detect keypoints, match, compute the fundamental matrix, recover pose, and triangulate to get 3D points. Print results at each stage.
