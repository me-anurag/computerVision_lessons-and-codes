# %% [markdown]
# # Mini Project 01 — Mini SfM Pipeline on 3 Images
#
# Build a minimal Structure from Motion pipeline that takes 3 images of an object from different viewpoints. For each pair detect matches, recover relative pose, and triangulate points. Visualize all reconstructed 3D points in a combined scatter plot.
