# %% [markdown]
# # Activity 01 — Triangulate Matched Points and Print 3D Coordinates
#
# Given two calibrated views with known projection matrices and matched 2D point pairs, use cv2.triangulatePoints to compute 3D coordinates. Convert from homogeneous to Cartesian and print the 3D positions.
