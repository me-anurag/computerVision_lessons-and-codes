# %% [markdown]
# # Mini Project 01 — 3D Point Reconstructor
#
# Build a 3D reconstruction tool that takes two images with feature matches and camera calibration data, triangulates the matched points, and visualizes the resulting sparse 3D point cloud using matplotlib 3D scatter plot.
