# %% [markdown]
# # Mini Project 01 — Parking Lot Occupancy Detector
#
# Build a parking lot monitor using KNN background subtraction. Define parking spot ROIs, detect foreground in each ROI, and classify each spot as occupied or empty. Display the lot with color-coded spot status.
