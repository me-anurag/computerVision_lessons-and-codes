# %% [markdown]
# # Activity 01 — MOG2 vs KNN Subtractor: False Positive Comparison
#
# Apply both MOG2 and KNN background subtractors to the same video. Count false positive foreground pixels in a static region for each method. Display both foreground masks side by side for comparison.
