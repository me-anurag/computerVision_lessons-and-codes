# %% [markdown]
# # Mini Project 01 — People Counter
#
# Build a people counting tool using MOG2 background subtraction. Detect moving blobs in a video, draw bounding boxes around each person, and count the number crossing a virtual horizontal line in the frame.
