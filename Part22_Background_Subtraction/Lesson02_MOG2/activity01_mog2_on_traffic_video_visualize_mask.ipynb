# %% [markdown]
# # Activity 01 — MOG2 on Traffic Video: Visualize Foreground Mask
#
# Apply cv2.createBackgroundSubtractorMOG2 to a traffic video. Display the foreground mask alongside the original frame in real time. Observe how the model adapts to lighting changes over time.
