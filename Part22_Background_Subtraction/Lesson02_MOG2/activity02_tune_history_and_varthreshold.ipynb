# %% [markdown]
# # Activity 02 — Tune MOG2 history and varThreshold Parameters
#
# Test MOG2 with history values of 50, 200, and 500 and varThreshold values of 16, 50, and 100. Compare how these parameters affect sensitivity to slow vs fast changes and noise level in the foreground mask.
