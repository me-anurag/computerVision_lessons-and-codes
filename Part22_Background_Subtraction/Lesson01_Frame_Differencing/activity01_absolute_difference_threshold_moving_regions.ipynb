# %% [markdown]
# # Activity 01 — Absolute Difference Between Frames to Find Moving Regions
#
# Compute cv2.absdiff between frame 1 and frame 50 of a video. Threshold the difference image, apply morphological cleanup, and find contours around moving regions. Draw bounding boxes on the result.
