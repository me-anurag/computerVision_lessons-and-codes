# %% [markdown]
# # Mini Project 01 — Motion Detector
#
# Build a motion detection system using frame differencing. When significant motion is detected (total changed area above threshold), draw a red alert border around the frame and print a motion alert to the console.
