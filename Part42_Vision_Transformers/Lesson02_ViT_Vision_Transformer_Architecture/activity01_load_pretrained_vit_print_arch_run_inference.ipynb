# %% [markdown]
# # Activity 01 — Load Pretrained ViT, Print Architecture, Run Inference
#
# Load a pretrained ViT model (e.g. vit_b_16 from torchvision). Print the full architecture, count total parameters, preprocess an image into patches, run inference, and print the top-5 predicted classes.
