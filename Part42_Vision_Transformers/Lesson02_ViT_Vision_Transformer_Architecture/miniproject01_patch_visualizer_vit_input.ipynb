# %% [markdown]
# # Mini Project 01 — Patch Visualizer: How ViT Sees an Image
#
# Build a ViT input visualizer. Take any image, divide it into 16x16 patches (as ViT does), number each patch, and display the patch grid alongside the original image to show how ViT tokenizes visual input.
