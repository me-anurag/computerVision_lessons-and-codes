# %% [markdown]
# # Mini Project 01 — Zero-Shot Image Classifier Using CLIP
#
# Build a zero-shot classifier using CLIP. Given a set of images and a list of class name prompts, classify each image by finding the text prompt with the highest cosine similarity to the image embedding — no training required.
