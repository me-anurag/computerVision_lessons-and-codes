# %% [markdown]
# # Activity 01 — CLIP: Encode Image and Text Prompts, Compute Similarity
#
# Load a pretrained CLIP model. Encode one image and several text prompts. Compute cosine similarity between the image embedding and each text embedding. Print and rank the results.
