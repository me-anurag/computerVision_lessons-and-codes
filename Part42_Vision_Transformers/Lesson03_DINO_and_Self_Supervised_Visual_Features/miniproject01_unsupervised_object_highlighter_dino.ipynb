# %% [markdown]
# # Mini Project 01 — Unsupervised Object Highlighter Using DINO
#
# Build an object highlighting tool using DINO attention maps. Extract attention from a DINO model, threshold it to produce a binary mask of the attended region, and overlay it on the original image to highlight the main object.
