# %% [markdown]
# # Activity 01 — DINO Attention Maps: Unsupervised Object Highlighting
#
# Load a pretrained DINO ViT model. Extract the self-attention maps from the last layer. Average attention across heads and upsample to image resolution. Display the attention map as a heatmap — observe how it highlights objects without any labels.
