# %% [markdown]
# # Activity 01 — Implement Scaled Dot-Product Attention from Scratch
#
# Implement scaled dot-product attention in PyTorch: compute Q, K, V matrices, compute attention scores (QK^T / sqrt(d_k)), apply softmax, and multiply by V. Verify output shape and test on a toy input sequence.
