# %% [markdown]
# # Mini Project 01 — Attention Weight Visualizer
#
# Build an attention visualization tool. Compute attention weights for a simple self-attention layer and display them as a heatmap, showing which input positions attend most strongly to each other.
