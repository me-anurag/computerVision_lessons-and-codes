# %% [markdown]
# # Activity 01 — Swin Transformer vs ViT: Inference Speed and Feature Quality
#
# Load pretrained Swin-T and ViT-B/16 models. Run inference on the same images. Compare top-1 accuracy, inference time, and parameter count. Discuss how Swin's window-based attention enables efficient dense prediction.
