# %% [markdown]
# # Mini Project 01 — Swin vs ViT Comparator
#
# Build a model comparison tool that runs Swin Transformer and ViT on a set of classification test images, reports accuracy, inference time, and memory usage for each, and produces a formatted comparison report.
