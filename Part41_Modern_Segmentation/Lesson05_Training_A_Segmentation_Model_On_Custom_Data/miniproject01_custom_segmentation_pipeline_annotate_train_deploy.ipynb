# %% [markdown]
# # Mini Project 01 — Custom Segmentation Pipeline: Annotate → Train → Evaluate → Deploy
#
# Build a complete segmentation pipeline. Annotate images with polygon masks, prepare the dataset, fine-tune SegFormer, evaluate with mIoU, export to ONNX, and run inference on new images.
