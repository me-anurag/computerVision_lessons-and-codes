# %% [markdown]
# # Activity 01 — Prepare Custom Segmentation Dataset and Fine-Tune SegFormer
#
# Prepare a small custom segmentation dataset (50 images with pixel masks). Define the DataLoader, loss function (cross entropy + dice), and training loop. Fine-tune a pretrained SegFormer for 10 epochs and evaluate on a validation set.
