# %% [markdown]
# # Activity 01 — Mask R-CNN: Extract Per-Instance Masks and Count per Class
#
# Run a pretrained Mask R-CNN on an image. Extract each instance's binary mask and class label. Print a count summary of how many instances of each class were detected. Draw all masks and boxes.
