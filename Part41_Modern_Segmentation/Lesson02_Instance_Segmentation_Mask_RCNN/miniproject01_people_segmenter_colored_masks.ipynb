# %% [markdown]
# # Mini Project 01 — People Segmenter with Unique Colored Masks
#
# Build a people segmentation tool using Mask R-CNN. Filter detections to the 'person' class only. Draw each detected person's mask in a unique random color and overlay it on the original image.
