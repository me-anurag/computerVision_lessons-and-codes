# %% [markdown]
# # Mini Project 01 — Real-Time SegFormer Segmentation on Webcam
#
# Build a live segmentation demo. Run SegFormer inference on each webcam frame and overlay the colored class mask semi-transparently on the original frame in real time, with the class legend displayed on screen.
