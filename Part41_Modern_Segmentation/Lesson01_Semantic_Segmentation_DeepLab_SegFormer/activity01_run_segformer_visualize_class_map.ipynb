# %% [markdown]
# # Activity 01 — Run SegFormer Inference and Visualize Class Map
#
# Load a pretrained SegFormer model from HuggingFace. Run inference on an image. Decode the output class predictions, apply a color palette, and display the colorized semantic segmentation map.
