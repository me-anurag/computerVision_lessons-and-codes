# %% [markdown]
# # Mini Project 01 — Click-to-Segment Tool Using SAM
#
# Build an interactive segmentation tool using SAM. The user clicks on any object in an image with a mouse callback, the click coordinates are passed as a point prompt to SAM, and the segmented object mask is immediately displayed.
