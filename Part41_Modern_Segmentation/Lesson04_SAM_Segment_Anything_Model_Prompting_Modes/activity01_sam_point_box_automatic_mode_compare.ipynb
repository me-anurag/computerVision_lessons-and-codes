# %% [markdown]
# # Activity 01 — SAM: Point Prompt, Box Prompt, and Automatic Mode
#
# Use the Segment Anything Model (SAM) in three prompting modes: point prompt (click a point), box prompt (draw a rectangle), and automatic mode (segment everything). Display and compare outputs from each mode.
