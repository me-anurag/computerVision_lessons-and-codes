# %% [markdown]
# # Mini Project 01 — Scene Parser: Fully Labeled Image
#
# Build a scene parsing tool using panoptic segmentation. Run a panoptic model on a street scene image and produce a clean output where every pixel is colored and labeled with its class name.
