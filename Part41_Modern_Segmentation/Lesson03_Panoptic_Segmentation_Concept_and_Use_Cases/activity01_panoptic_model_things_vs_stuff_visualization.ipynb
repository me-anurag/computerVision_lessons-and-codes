# %% [markdown]
# # Activity 01 — Panoptic Segmentation: Visualize Things vs Stuff
#
# Run a panoptic segmentation model on an image. Separate the output into 'things' (countable objects: people, cars) and 'stuff' (amorphous regions: sky, road). Visualize each category with distinct color schemes.
