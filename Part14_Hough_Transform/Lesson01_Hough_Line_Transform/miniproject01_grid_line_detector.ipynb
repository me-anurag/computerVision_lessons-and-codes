# %% [markdown]
# # Mini Project 01 — Grid Line Detector
#
# Build a grid line detector for scanned forms or spreadsheet images. Use Hough line transform to find all horizontal and vertical lines, filter them by angle, and draw them overlaid on the original image.
