# %% [markdown]
# # Activity 01 — Hough Line Transform on a Chessboard Image
#
# Apply cv2.HoughLines to a chessboard image after Canny edge detection. Convert rho/theta to Cartesian line endpoints and draw all detected lines. Observe how the full Hough transform detects infinite lines.
