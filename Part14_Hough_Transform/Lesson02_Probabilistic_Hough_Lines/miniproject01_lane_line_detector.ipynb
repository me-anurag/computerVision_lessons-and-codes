# %% [markdown]
# # Mini Project 01 — Lane Line Detector
#
# Build a lane line detector for a road image. Apply probabilistic Hough lines, filter detected line segments by their angle to keep only near-vertical road lane lines, and draw them overlaid on the original image.
