# %% [markdown]
# # Activity 01 — Standard vs Probabilistic Hough Lines Comparison
#
# Apply both cv2.HoughLines and cv2.HoughLinesP to the same image. Count the number of lines detected by each, compare the visual results, and measure the execution time of both methods.
