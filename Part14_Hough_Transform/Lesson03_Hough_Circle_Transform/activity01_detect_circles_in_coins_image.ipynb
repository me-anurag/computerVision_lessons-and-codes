# %% [markdown]
# # Activity 01 — Detect Circles in a Coins Image
#
# Apply cv2.HoughCircles to an image of coins. Tune the param1 (Canny threshold), param2 (accumulator threshold), minRadius, and maxRadius parameters until all coins are correctly detected. Draw detected circles.
