# %% [markdown]
# # Mini Project 01 — Coin Detector and Counter
#
# Build a coin detection and counting tool using Hough Circle Transform. Detect all circular coins in an image, draw each with its center point, and display the total coin count as a text overlay.
