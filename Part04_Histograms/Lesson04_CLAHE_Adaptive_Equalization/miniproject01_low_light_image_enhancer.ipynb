# %% [markdown]
# # Mini Project 01 — Low-Light Image Enhancer
#
# Build a low-light enhancement tool using CLAHE. Convert the image to LAB, apply CLAHE only to the L channel, convert back to BGR, and compare the result with the original dark image.
