# %% [markdown]
# # Activity 01 — Global Equalization vs CLAHE on a Face Photo
#
# Apply global histogram equalization and CLAHE to the same face photo with mixed lighting. Display all three versions (original, global EQ, CLAHE) side by side and compare local contrast improvement.
