# %% [markdown]
# # Activity 02 — Tune clipLimit and tileGridSize Parameters
#
# Experiment with different clipLimit values (1, 2, 5, 10) and tileGridSize values ((4,4), (8,8), (16,16)) and display a grid of results to understand how each parameter affects contrast amplification.
