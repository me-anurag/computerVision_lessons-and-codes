# %% [markdown]
# # Mini Project 01 — Skin Region Detector
#
# Build a skin region detector using histogram backprojection. Sample skin color from a small ROI, backproject across the full image, threshold and clean up with morphological ops, and draw contours around detected skin regions.
