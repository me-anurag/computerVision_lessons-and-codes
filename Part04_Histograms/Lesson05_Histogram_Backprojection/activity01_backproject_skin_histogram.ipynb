# %% [markdown]
# # Activity 01 — Backproject a Skin Color Histogram
#
# Manually select a skin-colored ROI from a portrait image, build its HSV histogram, and use cv2.calcBackProject to create a probability map highlighting all skin-colored regions in the full image.
