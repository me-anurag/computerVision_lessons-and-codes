# %% [markdown]
# # Activity 02 — Color Equalization: Wrong Way vs Correct Way
#
# Equalize a color image the wrong way (applying equalizeHist to all 3 BGR channels) and the correct way (equalizing only the V channel after converting to HSV). Compare both results.
