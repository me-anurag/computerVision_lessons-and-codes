# %% [markdown]
# # Activity 01 — Equalize a Dark Image and Compare Histograms
#
# Apply cv2.equalizeHist to a dark grayscale image. Show the original and equalized images side by side along with their histograms to visualize how equalization spreads the intensity distribution.
