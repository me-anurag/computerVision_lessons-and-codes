# %% [markdown]
# # Mini Project 01 — Before/After Equalizer
#
# Build a tool that takes any image, applies histogram equalization, and displays the original and equalized versions side by side along with their histograms in a single figure.
