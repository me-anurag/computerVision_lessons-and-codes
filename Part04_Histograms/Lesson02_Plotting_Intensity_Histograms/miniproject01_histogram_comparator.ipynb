# %% [markdown]
# # Mini Project 01 — Histogram Comparator
#
# Load two images, plot their histograms overlaid on the same axes, and compute a numerical similarity score between them using cv2.compareHist with the correlation method.
