# %% [markdown]
# # Activity 01 — Plot Per-Channel Histogram with Overlapping Lines
#
# Compute and plot the histogram for each B, G, R channel of a color image on a single matplotlib axes with overlapping colored lines. Add a legend and proper axis labels.
