# %% [markdown]
# # Mini Project 01 — Histogram Dashboard
#
# Build a matplotlib figure that shows an image and its RGB histogram side by side. The histogram should plot all 3 channels (B in blue, G in green, R in red) as overlapping lines.
