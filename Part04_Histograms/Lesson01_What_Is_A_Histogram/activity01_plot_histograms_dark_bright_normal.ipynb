# %% [markdown]
# # Activity 01 — Plot Histograms of Dark, Bright, and Normal Images
#
# Load a dark image, a bright image, and a normally exposed image. Plot the intensity histogram for each and describe how the histogram shape reflects the image's exposure.
