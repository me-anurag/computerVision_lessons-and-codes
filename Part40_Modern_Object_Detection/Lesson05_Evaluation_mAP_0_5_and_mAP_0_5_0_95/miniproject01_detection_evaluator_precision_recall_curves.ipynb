# %% [markdown]
# # Mini Project 01 — Detection Evaluator with Precision-Recall Curves
#
# Build a detection evaluation tool. Given model predictions and ground truth annotations, compute mAP@0.5 and mAP@0.5:0.95 per class and overall. Plot precision-recall curves for each class in a grid.
