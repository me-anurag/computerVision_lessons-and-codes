# %% [markdown]
# # Activity 01 — Compute mAP@0.5 Manually and Verify with torchmetrics
#
# Manually compute mAP@0.5 on a small detection result set: match predictions to ground truth by IoU, build precision-recall curves per class, compute AP per class, and average. Verify against torchmetrics.detection.MeanAveragePrecision.
