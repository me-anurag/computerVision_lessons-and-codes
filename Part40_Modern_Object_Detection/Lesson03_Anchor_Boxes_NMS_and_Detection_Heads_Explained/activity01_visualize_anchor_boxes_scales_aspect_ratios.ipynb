# %% [markdown]
# # Activity 01 — Visualize Anchor Boxes at Different Scales and Aspect Ratios
#
# Draw anchor boxes on an image for a given feature map size. Show anchors at 3 scales and 3 aspect ratios (9 anchors per location). Illustrate how anchors cover different object sizes and shapes.
