# %% [markdown]
# # Mini Project 01 — Anchor Box Visualizer
#
# Build an anchor box visualization tool. Given a feature map size, anchor scales, and aspect ratios, draw all anchors at every grid location on an image. Color-code anchors by scale to show the full anchor coverage.
