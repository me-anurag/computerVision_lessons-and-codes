# %% [markdown]
# # Mini Project 01 — Detection Paradigm Comparison: YOLOv8 vs Faster R-CNN
#
# Run YOLOv8 (one-stage) and Faster R-CNN (two-stage) on the same set of test images. Compare inference speed (FPS), detection accuracy, and behavior on small vs large objects. Summarize findings in a table.
