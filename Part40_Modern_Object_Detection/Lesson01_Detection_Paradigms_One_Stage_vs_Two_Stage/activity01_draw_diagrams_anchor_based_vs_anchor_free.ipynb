# %% [markdown]
# # Activity 01 — Draw Diagrams Comparing Anchor-Based vs Anchor-Free Detectors
#
# Create annotated diagrams illustrating the architecture differences between one-stage anchor-based (YOLO), one-stage anchor-free (FCOS), and two-stage (Faster R-CNN) detectors. Label key components of each.
