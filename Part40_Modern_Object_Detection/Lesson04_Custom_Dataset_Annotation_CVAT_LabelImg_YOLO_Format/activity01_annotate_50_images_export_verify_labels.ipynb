# %% [markdown]
# # Activity 01 — Annotate 50 Images in CVAT, Export in YOLO Format, Verify Labels
#
# Annotate 50 images using CVAT or LabelImg. Export in YOLO format. Write a verification script that checks every image has a corresponding .txt label file with valid bounding box coordinates.
