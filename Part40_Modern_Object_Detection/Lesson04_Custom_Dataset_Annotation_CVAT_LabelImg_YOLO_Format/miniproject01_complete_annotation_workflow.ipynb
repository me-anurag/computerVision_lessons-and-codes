# %% [markdown]
# # Mini Project 01 — Complete Annotation Workflow: Annotate → Split → Augment → Verify
#
# Build a complete dataset preparation workflow. Annotate images, split into train/val/test (70/20/10), apply augmentations using Albumentations, and run a final validation check on the entire dataset structure.
