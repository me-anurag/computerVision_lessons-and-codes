# %% [markdown]
# # Mini Project 01 — Custom YOLOv8 Detector: Annotate → Train → Deploy on Webcam
#
# Build a complete custom detector. Annotate 200 images of a chosen object, train YOLOv8 for 50 epochs, evaluate on a held-out test set, and deploy the trained model on a live webcam feed.
