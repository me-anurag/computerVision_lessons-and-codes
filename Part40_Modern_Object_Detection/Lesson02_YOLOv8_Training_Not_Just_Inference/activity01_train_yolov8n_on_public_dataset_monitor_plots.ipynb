# %% [markdown]
# # Activity 01 — Train YOLOv8n on a Public Dataset and Monitor Training Plots
#
# Download a small public detection dataset. Train YOLOv8n using the Ultralytics API. Monitor training using the built-in loss and mAP plots. Print final validation mAP.
