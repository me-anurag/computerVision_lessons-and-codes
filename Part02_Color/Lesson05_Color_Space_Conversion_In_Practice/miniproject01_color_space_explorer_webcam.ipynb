# %% [markdown]
# # Mini Project 01 — Color Space Explorer on Webcam
#
# Build a live webcam tool where keyboard keys switch the display between BGR, HSV, LAB, YCrCb, and Grayscale views in real time. Show the current color space name as text overlay.
