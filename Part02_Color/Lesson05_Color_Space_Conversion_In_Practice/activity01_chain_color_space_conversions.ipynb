# %% [markdown]
# # Activity 01 — Chain Color Space Conversions
#
# Convert one image step by step through BGR → HSV → LAB → Grayscale. Print the shape and dtype at each step and display all intermediate results.
