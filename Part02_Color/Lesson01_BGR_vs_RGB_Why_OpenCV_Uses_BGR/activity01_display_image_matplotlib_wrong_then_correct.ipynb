# %% [markdown]
# # Activity 01 — Display Image with Matplotlib: Wrong then Correct
#
# Load an image with OpenCV, display it directly with matplotlib (observe wrong colors), then convert BGR to RGB using cvtColor and display again correctly.
