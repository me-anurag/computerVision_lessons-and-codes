# %% [markdown]
# # Mini Project 01 — Color Channel Visualizer
#
# Build a tool that takes any image and shows all 3 channels side by side — once as raw grayscale and once as tinted (blue channel in blue, green in green, red in red).
