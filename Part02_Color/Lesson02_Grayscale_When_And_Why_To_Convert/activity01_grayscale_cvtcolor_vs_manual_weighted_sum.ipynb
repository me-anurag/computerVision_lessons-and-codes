# %% [markdown]
# # Activity 01 — Grayscale: cvtColor vs Manual Weighted Sum
#
# Convert an image to grayscale using cv2.cvtColor, then manually compute grayscale as 0.114*B + 0.587*G + 0.299*R using NumPy. Compare both results pixel by pixel.
