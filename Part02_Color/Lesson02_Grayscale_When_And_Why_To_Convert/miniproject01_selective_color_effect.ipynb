# %% [markdown]
# # Mini Project 01 — Selective Color Effect
#
# Convert an image to grayscale but keep one specific color (e.g. red objects) in full color. Use HSV masking to isolate the target color and blend it back onto the grayscale background.
