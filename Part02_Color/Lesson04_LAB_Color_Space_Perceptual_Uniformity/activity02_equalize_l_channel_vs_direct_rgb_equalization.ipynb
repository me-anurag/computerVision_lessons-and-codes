# %% [markdown]
# # Activity 02 — Equalize L Channel vs Direct RGB Equalization
#
# Apply histogram equalization directly to all 3 BGR channels (wrong way) and compare it with equalizing only the L channel in LAB space (correct way). Show both results.
