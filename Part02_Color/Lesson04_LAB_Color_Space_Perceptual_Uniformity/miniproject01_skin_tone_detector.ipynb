# %% [markdown]
# # Mini Project 01 — Skin Tone Detector
#
# Use LAB color space thresholds to detect and mask skin tone regions in a portrait image. Draw contours around detected skin regions and display the result.
