# %% [markdown]
# # Activity 01 — Display LAB Channels Separately
#
# Convert an image to LAB color space and display the L, A, and B channels as individual grayscale images. Describe what each channel represents perceptually.
