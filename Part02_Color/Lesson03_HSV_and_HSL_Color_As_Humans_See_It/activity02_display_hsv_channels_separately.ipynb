# %% [markdown]
# # Activity 02 — Display HSV Channels Separately
#
# Split an HSV image into H, S, V channels and display each one as a grayscale image. Write observations about what each channel encodes visually.
