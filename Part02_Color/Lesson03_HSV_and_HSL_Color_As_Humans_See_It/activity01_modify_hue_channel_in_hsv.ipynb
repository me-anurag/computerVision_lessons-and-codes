# %% [markdown]
# # Activity 01 — Modify the Hue Channel in HSV
#
# Convert an image to HSV, add a constant value to the H channel to shift all colors, convert back to BGR, and display the color-shifted result.
