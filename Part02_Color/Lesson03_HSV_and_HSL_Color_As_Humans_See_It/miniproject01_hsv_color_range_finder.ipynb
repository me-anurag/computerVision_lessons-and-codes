# %% [markdown]
# # Mini Project 01 — HSV Color Range Finder
#
# Build a trackbar UI with 6 sliders (Hmin, Smin, Vmin, Hmax, Smax, Vmax). Apply cv2.inRange using the current slider values and show the live binary mask and the masked color image side by side.
