# %% [markdown]
# # Mini Project 01 — Instance Segmentation Visualizer with Random Color Masks
#
# Build an instance segmentation visualizer. Run Mask R-CNN on an image and draw each instance's binary mask filled with a unique random color, with the class label and confidence overlaid on the bounding box.
