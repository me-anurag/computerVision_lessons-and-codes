# %% [markdown]
# # Activity 01 — Run Mask R-CNN and Print Detected Instances with Masks
#
# Load a Mask R-CNN model. Run inference on an image. For each detected instance print: class name, confidence score, bounding box coordinates, and mask shape. Draw boxes and masks on the image.
