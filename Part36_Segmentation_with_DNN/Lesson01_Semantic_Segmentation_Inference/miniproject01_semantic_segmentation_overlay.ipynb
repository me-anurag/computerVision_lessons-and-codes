# %% [markdown]
# # Mini Project 01 — Semantic Segmentation Overlay
#
# Build a segmentation overlay tool. Run semantic segmentation on an image, create a colored class mask, and blend it semi-transparently over the original image to produce an annotated visualization.
