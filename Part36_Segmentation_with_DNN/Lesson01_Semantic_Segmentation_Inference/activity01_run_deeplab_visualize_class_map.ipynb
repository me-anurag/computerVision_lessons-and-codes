# %% [markdown]
# # Activity 01 — Run DeepLab/FCN and Visualize Class Map
#
# Load a semantic segmentation model (DeepLab or FCN) in OpenCV DNN. Run inference on an image, decode the output class map, apply a color palette to each class, and display the colorized segmentation result.
