# %% [markdown]
# # Activity 01 — Frequency Spectra of Synthetic Images
#
# Generate synthetic images (a single horizontal sine wave, a vertical sine wave, and a checkerboard pattern). Compute and display the magnitude spectrum of each to build intuition about how spatial patterns appear in the frequency domain.
