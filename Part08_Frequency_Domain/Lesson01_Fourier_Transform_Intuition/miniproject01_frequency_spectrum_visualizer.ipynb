# %% [markdown]
# # Mini Project 01 — Frequency Spectrum Visualizer
#
# Build a tool that takes any image as input, computes its DFT, applies log scaling to the magnitude spectrum, and displays the original image and its centered frequency spectrum side by side.
