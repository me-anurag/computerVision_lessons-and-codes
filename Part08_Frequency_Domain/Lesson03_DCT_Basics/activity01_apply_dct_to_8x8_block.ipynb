# %% [markdown]
# # Activity 01 — Apply DCT to an 8x8 Image Block
#
# Extract an 8x8 pixel block from a grayscale image. Apply cv2.dct to it, display the coefficient matrix as a heatmap, and observe how most energy concentrates in the top-left low-frequency coefficients.
