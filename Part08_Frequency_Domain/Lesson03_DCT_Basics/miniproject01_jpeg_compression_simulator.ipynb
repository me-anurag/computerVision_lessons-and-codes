# %% [markdown]
# # Mini Project 01 — JPEG Compression Simulator
#
# Simulate JPEG compression by dividing an image into 8x8 blocks, applying DCT to each, zeroing out high-frequency coefficients, applying inverse DCT, and reassembling. Show quality degradation at different compression levels.
