# %% [markdown]
# # Activity 01 — Circular Mask Low-Pass and High-Pass Filters
#
# Create a circular mask in the frequency domain to implement a low-pass filter (blur) and its inverse as a high-pass filter (edges). Apply both to an image and compare with spatial domain equivalents.
