# %% [markdown]
# # Mini Project 01 — Frequency-Domain Sharpener
#
# Build an image sharpener that works in the frequency domain. Amplify high-frequency components using a high-pass filter mask, then reconstruct the image with inverse DFT. Compare with a spatial domain unsharp mask.
