# %% [markdown]
# # Activity 01 — Compute DFT, Shift Zero Frequency, Visualize Spectrum
#
# Compute the DFT of a grayscale image using cv2.dft, shift the zero-frequency component to the center with np.fft.fftshift, compute the log magnitude spectrum, and display it.
