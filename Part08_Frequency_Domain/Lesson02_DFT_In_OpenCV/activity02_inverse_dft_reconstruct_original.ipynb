# %% [markdown]
# # Activity 02 — Inverse DFT: Reconstruct the Original Image
#
# Take the DFT of an image, then apply the inverse DFT using cv2.idft. Verify that the reconstructed image matches the original by computing the mean absolute difference.
