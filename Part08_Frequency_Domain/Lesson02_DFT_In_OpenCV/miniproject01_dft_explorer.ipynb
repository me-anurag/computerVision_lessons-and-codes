# %% [markdown]
# # Mini Project 01 — DFT Explorer
#
# Build a side-by-side viewer showing an image and its magnitude spectrum. When the user clicks a point on the spectrum, print its frequency coordinates and the approximate spatial pattern that frequency corresponds to.
