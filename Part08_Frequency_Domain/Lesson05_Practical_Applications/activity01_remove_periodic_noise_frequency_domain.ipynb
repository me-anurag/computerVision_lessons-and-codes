# %% [markdown]
# # Activity 01 — Remove Periodic Noise in the Frequency Domain
#
# Take an image with synthetic periodic noise. Visualize its spectrum, identify the spike frequencies corresponding to the noise, zero them out, and reconstruct the cleaned image with inverse DFT.
