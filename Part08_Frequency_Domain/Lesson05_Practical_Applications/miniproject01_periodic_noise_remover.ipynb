# %% [markdown]
# # Mini Project 01 — Periodic Noise Remover
#
# Build a tool that detects and removes periodic noise from images. Compute the DFT, identify high-energy spikes in the spectrum, suppress them with a notch filter, and reconstruct the denoised image.
