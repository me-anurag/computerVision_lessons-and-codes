# %% [markdown]
# # Mini Project 01 — Face Tracker Using CamShift on Webcam
#
# Build a face tracker using CamShift. Initialize tracking using a manually selected face ROI, build a skin-color histogram, and track the face across live webcam frames with an adaptive-size tracking ellipse.
