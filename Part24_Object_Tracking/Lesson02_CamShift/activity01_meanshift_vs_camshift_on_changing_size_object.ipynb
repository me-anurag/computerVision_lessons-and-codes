# %% [markdown]
# # Activity 01 — MeanShift vs CamShift on an Object That Changes Size
#
# Track an object that moves toward and away from the camera using both MeanShift and CamShift. Observe that CamShift dynamically resizes its tracking window while MeanShift uses a fixed window.
