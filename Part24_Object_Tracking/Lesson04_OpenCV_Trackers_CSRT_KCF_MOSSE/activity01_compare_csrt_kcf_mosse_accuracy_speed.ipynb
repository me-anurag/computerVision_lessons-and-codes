# %% [markdown]
# # Activity 01 — Compare CSRT, KCF, and MOSSE Trackers: Accuracy and Speed
#
# Select the same ROI in a video and track it separately using CSRT, KCF, and MOSSE trackers. Measure FPS for each tracker and compare tracking accuracy when the object moves fast or gets partially occluded.
