# %% [markdown]
# # Mini Project 01 — Multi-Object Tracker Using CSRT
#
# Build a multi-object tracker that initializes 3 separate CSRT trackers on 3 different ROIs in a video. Draw each tracker's bounding box in a different color and display all tracked objects simultaneously.
