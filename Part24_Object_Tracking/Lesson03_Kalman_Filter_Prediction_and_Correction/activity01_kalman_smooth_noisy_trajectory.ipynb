# %% [markdown]
# # Activity 01 — Kalman Filter: Smooth a Noisy Simulated Trajectory
#
# Simulate a moving point with Gaussian noise added to its position. Apply a Kalman filter to predict and correct the trajectory. Plot the noisy measurements, the true path, and the Kalman-smoothed path together.
