# %% [markdown]
# # Mini Project 01 — Trajectory Smoother
#
# Build a trajectory smoothing tool using a Kalman filter. Take a series of noisy 2D position measurements (simulated GPS-like data), apply Kalman filtering, and display the raw vs smoothed trajectory overlaid on a canvas.
