# %% [markdown]
# # Mini Project 01 — Ball Tracker Using MeanShift
#
# Build a ball tracker using MeanShift. Initialize tracking on the ball's position in the first frame, track it through a sports video clip, and draw the tracking window and trajectory path on each frame.
