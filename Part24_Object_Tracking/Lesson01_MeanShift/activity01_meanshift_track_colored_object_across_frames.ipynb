# %% [markdown]
# # Activity 01 — MeanShift: Track Colored Object Across Frames
#
# Select a colored object ROI in the first frame. Build its HSV histogram and create a backprojection. Use cv2.meanShift to track the object across subsequent frames, drawing the tracking window on each frame.
