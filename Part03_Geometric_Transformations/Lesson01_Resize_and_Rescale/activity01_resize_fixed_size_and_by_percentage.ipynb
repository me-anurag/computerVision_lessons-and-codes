# %% [markdown]
# # Activity 01 — Resize to Fixed Size and by Percentage
#
# Resize an image to a fixed resolution (300x300), then resize it to 50% and 200% of its original size. Print dimensions at each step and display all results.
