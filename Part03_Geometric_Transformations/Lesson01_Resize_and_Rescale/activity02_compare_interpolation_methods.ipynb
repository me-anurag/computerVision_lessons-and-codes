# %% [markdown]
# # Activity 02 — Compare All 4 Interpolation Methods
#
# Resize the same image using INTER_NEAREST, INTER_LINEAR, INTER_CUBIC, and INTER_AREA. Crop a small patch from each result and display them side by side to compare quality.
