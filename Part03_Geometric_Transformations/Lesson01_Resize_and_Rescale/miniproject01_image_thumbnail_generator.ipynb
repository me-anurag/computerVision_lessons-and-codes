# %% [markdown]
# # Mini Project 01 — Image Thumbnail Generator
#
# Build a tool that takes any image and generates 3 thumbnail versions at 128px, 256px, and 512px on the longest side while preserving the original aspect ratio. Save all three.
