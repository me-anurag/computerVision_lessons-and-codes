# %% [markdown]
# # Activity 01 — Rotate Image at 45, 90, and 180 Degrees
#
# Rotate an image by 45°, 90°, and 180° around its center using cv2.getRotationMatrix2D and cv2.warpAffine. Observe how corners get cropped at non-right-angle rotations.
