# %% [markdown]
# # Mini Project 01 — Rotation Corrector
#
# Build a tool that takes a skewed or tilted document image. The user inputs the correction angle, the tool rotates the image to straighten it, and saves the corrected version.
