# %% [markdown]
# # Activity 02 — Rotate Without Cropping by Expanding the Canvas
#
# Rotate an image by 45° without cropping any content. Compute the new canvas size needed to fit the rotated image fully and adjust the translation in the rotation matrix accordingly.
