# %% [markdown]
# # Mini Project 01 — Document Scanner Front-End
#
# Build an interactive tool where the user clicks 4 corners of a document on screen. The tool computes the perspective transform, warps the document to a flat A4-proportioned image, and saves it.
