# %% [markdown]
# # Activity 01 — Warp a Document to a Flat Rectangle
#
# Manually define the 4 corner coordinates of a book or document in a photo. Use cv2.getPerspectiveTransform and cv2.warpPerspective to produce a flat, top-down view.
