# %% [markdown]
# # Activity 02 — Build a Shear Transformation Using Custom Affine Matrix
#
# Construct a shear transformation manually by defining a custom 2x3 affine matrix with shear values. Apply it to an image and observe the shearing effect.
