# %% [markdown]
# # Activity 01 — Compute and Apply Affine Transformation from 3 Points
#
# Define 3 source points and 3 destination points, compute the affine transformation matrix using cv2.getAffineTransform, apply it with warpAffine, and display the result.
