# %% [markdown]
# # Mini Project 01 — Straighten Scanned Document
#
# Build a 3-point affine correction tool. The user clicks 3 points on a skewed scanned document and specifies where those points should map to. The tool applies the affine warp and saves the straightened document.
