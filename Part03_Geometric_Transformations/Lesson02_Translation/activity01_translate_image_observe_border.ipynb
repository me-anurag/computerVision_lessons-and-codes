# %% [markdown]
# # Activity 01 — Translate Image and Observe Border Filling
#
# Translate an image by (tx=50, ty=100) pixels using a translation matrix and cv2.warpAffine. Observe what fills the empty border region and experiment with different border modes.
