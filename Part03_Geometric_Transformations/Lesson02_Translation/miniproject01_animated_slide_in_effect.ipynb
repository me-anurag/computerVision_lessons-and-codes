# %% [markdown]
# # Mini Project 01 — Animated Slide-In Effect
#
# Generate a sequence of frames where an image slides in from the left edge to the center of the canvas. Save all frames as individual images or as a video file.
