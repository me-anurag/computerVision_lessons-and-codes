# %% [markdown]
# # Activity 01 — Run MiDaS and Visualize Relative Depth Map
#
# Load a pretrained MiDaS model. Run inference on an indoor and outdoor image. Apply a colormap to the relative depth map and display it. Identify and annotate near (warm colors) vs far (cool colors) regions.
