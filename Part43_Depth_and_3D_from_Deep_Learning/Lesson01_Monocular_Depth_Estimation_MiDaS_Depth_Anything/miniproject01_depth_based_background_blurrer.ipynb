# %% [markdown]
# # Mini Project 01 — Depth-Based Background Blurrer
#
# Build a depth-of-field simulator using MiDaS depth estimation. Estimate the depth map of an image, define a depth threshold, apply Gaussian blur to all pixels beyond the threshold, and composite with the sharp foreground.
