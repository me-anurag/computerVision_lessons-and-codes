# %% [markdown]
# # Mini Project 01 — Point Cloud Shape Classifier Using PointNet
#
# Build a 3D shape classifier using PointNet. Load point cloud samples of simple shapes (chair, table, lamp) from ModelNet. Run PointNet inference on each, display the 3D shape with Open3D, and print the predicted class.
