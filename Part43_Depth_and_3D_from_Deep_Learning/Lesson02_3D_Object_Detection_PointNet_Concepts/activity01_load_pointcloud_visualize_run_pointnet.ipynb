# %% [markdown]
# # Activity 01 — Load a Point Cloud, Visualize with Open3D, Run PointNet
#
# Load a 3D point cloud from a .ply or .xyz file. Visualize it using Open3D. Run a pretrained PointNet model on a sampled point cloud to classify the 3D shape. Print the predicted class name.
