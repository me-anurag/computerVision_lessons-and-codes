# %% [markdown]
# # Mini Project 01 — NeRF Scene Viewer
#
# Build a NeRF viewer that loads a pretrained NeRF model and lets the user navigate around the scene. Use keyboard controls (WASD + arrow keys) to change the camera viewpoint and render new frames interactively.
