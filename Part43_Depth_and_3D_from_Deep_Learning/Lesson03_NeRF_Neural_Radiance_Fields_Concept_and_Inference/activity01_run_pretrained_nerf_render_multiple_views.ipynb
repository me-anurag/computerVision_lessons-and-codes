# %% [markdown]
# # Activity 01 — Run a Pretrained NeRF and Render Multiple Viewpoints
#
# Load a pretrained NeRF model for a provided scene. Render the scene from 8 different viewpoints by specifying camera pose matrices. Display all rendered views in a grid to demonstrate novel view synthesis.
