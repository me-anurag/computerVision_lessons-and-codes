# %% [markdown]
# # Mini Project 01 — Cell/Colony Counter
#
# Build a cell or colony counting tool using SimpleBlobDetector. Configure it for roughly circular blobs of expected size, detect all colonies in a biology-style image, draw circles around each, and display the total count.
