# %% [markdown]
# # Activity 01 — Blob Detection: Filter by Area, Circularity, and Inertia
#
# Configure cv2.SimpleBlobDetector with different filter combinations: area only, circularity only, inertia only, and all combined. Display results for each configuration and observe how each filter selects different blob types.
