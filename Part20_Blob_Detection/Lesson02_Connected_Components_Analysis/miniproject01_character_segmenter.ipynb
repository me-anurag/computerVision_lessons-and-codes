# %% [markdown]
# # Mini Project 01 — Character Segmenter
#
# Build a character segmentation tool for printed text images. Use connected components to isolate each individual character, draw a bounding box around each one, and display them in left-to-right reading order.
