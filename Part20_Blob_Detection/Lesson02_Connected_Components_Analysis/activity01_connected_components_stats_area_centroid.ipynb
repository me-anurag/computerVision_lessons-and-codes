# %% [markdown]
# # Activity 01 — Connected Components with Stats: Area and Centroid
#
# Apply cv2.connectedComponentsWithStats to a binary image. Print the area and centroid of each labeled component. Draw each component in a unique random color and label it with its area value.
