# %% [markdown]
# # Mini Project 01 — Superpixel Visualizer
#
# Build a 3-panel superpixel visualizer showing: the original image, the image with superpixel boundaries drawn, and a version where each superpixel is filled with its mean color — all displayed side by side.
