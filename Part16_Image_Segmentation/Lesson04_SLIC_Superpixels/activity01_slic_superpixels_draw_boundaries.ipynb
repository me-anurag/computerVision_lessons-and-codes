# %% [markdown]
# # Activity 01 — Generate SLIC Superpixels and Draw Boundaries
#
# Use scikit-image SLIC to generate superpixels on an image. Draw the superpixel boundaries in green over the original image. Vary the number of segments (100, 300, 500) and observe how superpixel size changes.
