# %% [markdown]
# # Activity 01 — Mean Shift with Varying Spatial and Color Radii
#
# Apply cv2.pyrMeanShiftFiltering with different spatial radius (sp) and color radius (sr) values. Display a grid of results showing how larger radii produce coarser segmentation and smaller radii produce finer regions.
