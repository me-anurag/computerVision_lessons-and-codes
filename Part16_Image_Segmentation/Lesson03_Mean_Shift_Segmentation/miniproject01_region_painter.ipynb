# %% [markdown]
# # Mini Project 01 — Region Painter
#
# Build a region painter using mean shift segmentation. Segment the image, find the contours of each region, and fill every region with its mean color to produce a flat, posterized painting effect.
