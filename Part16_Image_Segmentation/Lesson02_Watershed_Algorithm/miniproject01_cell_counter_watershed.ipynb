# %% [markdown]
# # Mini Project 01 — Cell Counter Using Watershed
#
# Build a cell counting tool that uses the watershed algorithm to separate and count touching circular objects (cells, colonies). Display each segmented cell in a different color and print the total count.
