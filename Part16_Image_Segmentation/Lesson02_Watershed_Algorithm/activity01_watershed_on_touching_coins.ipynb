# %% [markdown]
# # Activity 01 — Watershed Segmentation on Touching Coins
#
# Apply the watershed algorithm to separate touching coins. Use distance transform to find sure foreground, define sure background and unknown regions, label markers, and apply cv2.watershed. Color each segment differently.
