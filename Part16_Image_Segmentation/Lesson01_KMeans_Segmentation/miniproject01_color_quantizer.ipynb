# %% [markdown]
# # Mini Project 01 — Color Quantizer
#
# Build a color quantization tool using K-means. Reduce any image to N distinct colors (user-specified), reconstruct it using only those N colors, and display the original and quantized versions side by side.
