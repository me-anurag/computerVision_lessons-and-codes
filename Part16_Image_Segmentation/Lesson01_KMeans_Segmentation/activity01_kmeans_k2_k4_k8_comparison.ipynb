# %% [markdown]
# # Activity 01 — K-Means Segmentation with K=2, K=4, K=8
#
# Apply K-means clustering (cv2.kmeans) to segment an image with K=2, K=4, and K=8 clusters. Reshape pixel data, cluster, and reconstruct the segmented image for each K. Display all results side by side.
