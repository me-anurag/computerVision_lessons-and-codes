# %% [markdown]
# # Mini Project 01 — Centroid Tracker
#
# Build a centroid labeling tool that detects all objects in an image, computes the centroid of each, draws a dot at each centroid, and labels them with their index number and pixel coordinates.
