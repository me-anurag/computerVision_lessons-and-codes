# %% [markdown]
# # Activity 01 — Compute Moments and Draw Centroid
#
# Compute image moments using cv2.moments for detected contours. Calculate the centroid (cx, cy) from M10/M00 and M01/M00. Draw the centroid as a dot on the image and print its coordinates.
