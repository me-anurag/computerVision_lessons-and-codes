# %% [markdown]
# # Activity 01 — Upright vs Rotated Bounding Boxes
#
# Detect contours in an image containing tilted objects. Draw both upright bounding rectangles (cv2.boundingRect) and minimum-area rotated rectangles (cv2.minAreaRect) around each. Compare how well each fits the object.
