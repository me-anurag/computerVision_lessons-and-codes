# %% [markdown]
# # Mini Project 01 — Object Measurement Tool
#
# Build a measurement tool that draws the minimum-area rotated bounding box around each detected object and prints its width and height in pixels alongside the object in the image.
