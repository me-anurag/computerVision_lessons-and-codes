# %% [markdown]
# # Mini Project 01 — Shape Matcher
#
# Build a shape matching tool using Hu moments. Given a template contour, compute its Hu moments and compare against all contours found in a scene image using cv2.matchShapes. Highlight the best matching contour.
