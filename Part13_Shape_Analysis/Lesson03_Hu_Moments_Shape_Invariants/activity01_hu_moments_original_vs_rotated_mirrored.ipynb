# %% [markdown]
# # Activity 01 — Hu Moments: Original vs Rotated vs Mirrored Shape
#
# Compute the 7 Hu moments for a shape. Then rotate it by 45° and mirror it horizontally, compute Hu moments again for each. Print all three sets and verify they are approximately equal, demonstrating invariance.
