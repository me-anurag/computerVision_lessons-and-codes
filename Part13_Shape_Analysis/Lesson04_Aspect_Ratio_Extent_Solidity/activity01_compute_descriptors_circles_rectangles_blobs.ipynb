# %% [markdown]
# # Activity 01 — Compute Aspect Ratio, Extent, and Solidity for Different Shapes
#
# Compute aspect ratio (width/height), extent (contour area / bounding box area), and solidity (contour area / convex hull area) for circles, rectangles, and irregular blobs. Print results in a table.
