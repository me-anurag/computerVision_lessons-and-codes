# %% [markdown]
# # Mini Project 01 — Shape Classifier
#
# Build a shape classifier that uses aspect ratio, extent, and solidity to classify each detected contour as circle, square, rectangle, or irregular shape. Draw each contour with its classification label.
