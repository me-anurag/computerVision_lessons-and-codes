# %% [markdown]
# # Activity 01 — Apply All 5 Threshold Types
#
# Apply THRESH_BINARY, THRESH_BINARY_INV, THRESH_TRUNC, THRESH_TOZERO, and THRESH_TOZERO_INV to the same grayscale image. Display all 5 results in a grid with their names as titles.
