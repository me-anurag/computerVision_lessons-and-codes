# %% [markdown]
# # Mini Project 01 — Object Silhouette Extractor
#
# Use binary thresholding on a high-contrast image to isolate the main object as a clean silhouette. Apply morphological cleanup to remove noise, then display the original image alongside the extracted silhouette.
