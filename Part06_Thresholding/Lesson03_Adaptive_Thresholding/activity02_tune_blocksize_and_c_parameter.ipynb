# %% [markdown]
# # Activity 02 — Tune blockSize and C Parameters
#
# Experiment with blockSize values (11, 21, 51) and C values (-5, 0, 5, 10) in adaptive thresholding. Display a grid of results to understand how each parameter controls local threshold sensitivity.
