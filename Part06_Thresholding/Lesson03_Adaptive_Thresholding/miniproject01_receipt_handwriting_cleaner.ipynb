# %% [markdown]
# # Mini Project 01 — Receipt/Handwriting Cleaner
#
# Build a cleaner for receipt or handwritten note images with uneven lighting. Apply adaptive Gaussian thresholding with tuned parameters to produce a clean, readable binary image.
