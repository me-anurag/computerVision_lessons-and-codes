# %% [markdown]
# # Activity 01 — Global vs Adaptive Mean vs Adaptive Gaussian
#
# Apply global thresholding, adaptive mean thresholding, and adaptive Gaussian thresholding to the same image with non-uniform lighting. Display all three results side by side and compare.
