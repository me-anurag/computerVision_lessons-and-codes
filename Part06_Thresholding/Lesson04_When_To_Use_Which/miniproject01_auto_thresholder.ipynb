# %% [markdown]
# # Mini Project 01 — Auto-Thresholder
#
# Build an intelligent thresholding tool that analyzes an image's histogram characteristics (bimodality, lighting uniformity) and automatically selects and applies the most appropriate thresholding method.
