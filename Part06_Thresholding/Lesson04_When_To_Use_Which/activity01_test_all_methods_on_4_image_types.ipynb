# %% [markdown]
# # Activity 01 — Test All Methods on 4 Image Types
#
# Take 4 test images (uniformly dark, uniformly bright, uneven lighting, bimodal histogram). Apply all thresholding methods to each and select the best result for each case with written justification.
