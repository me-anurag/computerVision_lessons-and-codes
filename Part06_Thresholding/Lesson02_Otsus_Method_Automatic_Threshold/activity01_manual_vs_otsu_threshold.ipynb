# %% [markdown]
# # Activity 01 — Manual Threshold vs Otsu on a Bimodal Image
#
# Apply manual thresholding at a guessed value vs Otsu's automatic method on a bimodal histogram image. Print the Otsu-computed threshold value and compare both results visually.
