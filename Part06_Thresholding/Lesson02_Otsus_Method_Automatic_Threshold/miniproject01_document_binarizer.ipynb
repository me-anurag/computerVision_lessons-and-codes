# %% [markdown]
# # Mini Project 01 — Document Binarizer
#
# Build a tool that takes a scanned document image, applies Gaussian blur followed by Otsu thresholding, and produces a clean black-and-white binary version suitable for OCR or printing.
