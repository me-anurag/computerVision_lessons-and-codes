# %% [markdown]
# # Activity 02 — Apply Gaussian Blur Before Otsu
#
# Apply Otsu thresholding directly to a noisy image, then apply Gaussian blur first and run Otsu again. Compare both binary results to observe how pre-blurring improves Otsu's performance.
