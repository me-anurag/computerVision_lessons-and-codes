# %% [markdown]
# # Mini Project 01 — Duplicate Image Detector
#
# Build a duplicate detection tool. Given two images, compute SIFT descriptors, apply BF matching, count good matches, and classify the pair as duplicates if the match count exceeds a threshold.
