# %% [markdown]
# # Activity 01 — BF Match Two Views of Same Object, Draw Top 20 Matches
#
# Take two images of the same object from different angles. Detect SIFT keypoints, extract descriptors, apply cv2.BFMatcher, sort matches by distance, and draw the top 20 matches using cv2.drawMatches.
