# %% [markdown]
# # Mini Project 01 — Book Cover Detector
#
# Build a book cover detector. Given a template image of a book cover, find it in a cluttered scene using SIFT matching + homography. Draw a quadrilateral around the detected cover in the scene image.
