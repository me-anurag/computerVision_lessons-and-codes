# %% [markdown]
# # Activity 01 — Compute Homography and Draw Projected Template Corners
#
# Use good matches to compute a homography matrix with cv2.findHomography (RANSAC). Project the 4 corners of the template image into the scene using cv2.perspectiveTransform and draw the detected object boundary.
