# %% [markdown]
# # Mini Project 01 — Descriptor Analyzer
#
# Build a descriptor analysis tool that extracts SIFT descriptors from an image, computes statistics (mean, std, min, max) across all descriptors, and visualizes the distribution of descriptor values as a histogram.
