# %% [markdown]
# # Activity 01 — SIFT Descriptor Shape and Bar Chart Visualization
#
# Extract SIFT descriptors from an image. Print the shape of the descriptor array. Select one descriptor and plot its 128 values as a bar chart to visualize the gradient histogram it encodes.
