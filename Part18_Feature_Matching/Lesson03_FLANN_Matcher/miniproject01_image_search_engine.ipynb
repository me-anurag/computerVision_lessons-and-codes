# %% [markdown]
# # Mini Project 01 — Image Search Engine
#
# Build a simple image search tool. Given a query image, extract SIFT descriptors and use FLANN matching to compare it against a folder of candidate images. Rank and display the most similar images by match count.
