# %% [markdown]
# # Activity 01 — FLANN vs BF Matcher Speed on Large Descriptor Sets
#
# Match two image pairs using both BFMatcher and FLANN. Measure and print execution time for each. Compare number of matches found and visual quality of results on images with many keypoints.
