# %% [markdown]
# # Mini Project 01 — Match Quality Visualizer
#
# Build a match visualizer that applies the ratio test and draws good matches in green and rejected matches in red on the same image, making it easy to see which matches pass or fail the quality filter.
