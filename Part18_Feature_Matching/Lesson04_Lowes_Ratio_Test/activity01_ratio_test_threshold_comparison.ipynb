# %% [markdown]
# # Activity 01 — Ratio Test with Thresholds 0.6, 0.7, and 0.8
#
# Apply Lowe's ratio test with thresholds of 0.6, 0.7, and 0.8 to a set of kNN matches. Count the number of good matches at each threshold and display the filtered matches to show the quality vs quantity tradeoff.
