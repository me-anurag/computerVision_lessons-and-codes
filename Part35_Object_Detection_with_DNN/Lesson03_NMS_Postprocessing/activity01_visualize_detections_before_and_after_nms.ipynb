# %% [markdown]
# # Activity 01 — Visualize All Raw Detections Before and After NMS
#
# Run object detection and visualize all raw detections before applying NMS (showing all overlapping boxes). Then apply cv2.dnn.NMSBoxes and show only the final detections to see how NMS removes duplicates.
