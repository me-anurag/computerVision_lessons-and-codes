# %% [markdown]
# # Mini Project 01 — NMS Visualizer with IOU Threshold Slider
#
# Build an NMS visualization tool with a trackbar controlling the IOU threshold (0.1 to 0.9). Show how changing the IOU threshold affects how aggressively overlapping boxes are suppressed.
