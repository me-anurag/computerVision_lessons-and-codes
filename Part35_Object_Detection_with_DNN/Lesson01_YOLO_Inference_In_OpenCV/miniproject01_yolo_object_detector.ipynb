# %% [markdown]
# # Mini Project 01 — YOLO Object Detector
#
# Build a complete YOLO detection tool. Load a YOLO ONNX model, preprocess the input, run inference, decode bounding boxes, apply NMS, and draw labeled boxes with confidence scores on any image or webcam frame.
