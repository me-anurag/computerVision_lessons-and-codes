# %% [markdown]
# # Activity 01 — Run YOLOv5 ONNX in OpenCV and Understand Raw Output
#
# Load a YOLOv5 ONNX model in OpenCV DNN. Run a forward pass on an image and print the raw output tensor shape. Understand what each dimension means: batch, anchors, (cx, cy, w, h, conf, class scores).
