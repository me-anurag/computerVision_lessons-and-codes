# %% [markdown]
# # Activity 01 — SSD MobileNet vs YOLO: Accuracy and Speed Comparison
#
# Run both SSD MobileNet and a YOLO model on the same set of test images. Count detections, measure inference time, and compare results for speed and detection quality.
