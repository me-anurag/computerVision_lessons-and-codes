# %% [markdown]
# # Mini Project 01 — Real-Time Object Counter
#
# Build a live object counting tool. Run object detection on each webcam frame and display a live count of how many instances of each detected class are present in the current frame.
