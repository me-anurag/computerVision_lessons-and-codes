# %% [markdown]
# # Activity 01 — List All Available DNN Backends and Targets
#
# Use cv2.dnn.getAvailableBackends() and cv2.dnn.getAvailableTargets() to list all computation backends (OpenCV, CUDA, OpenVINO) and targets (CPU, GPU, VPU) available on the current machine.
