# %% [markdown]
# # Mini Project 01 — DNN Environment Report
#
# Build a DNN environment report tool that prints all available backends, targets, whether CUDA is available, and the OpenCV version — formatted as a clean system summary for deployment planning.
