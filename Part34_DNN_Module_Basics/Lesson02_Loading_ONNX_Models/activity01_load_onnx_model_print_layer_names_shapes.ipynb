# %% [markdown]
# # Activity 01 — Load an ONNX Model and Print Layer Names and Shapes
#
# Load a pre-exported ONNX model using cv2.dnn.readNetFromONNX. Print the names of all layers and the input/output blob shapes to understand the model architecture.
