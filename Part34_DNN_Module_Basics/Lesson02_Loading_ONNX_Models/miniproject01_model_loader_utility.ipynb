# %% [markdown]
# # Mini Project 01 — Model Loader Utility
#
# Build a model inspection utility that loads any ONNX model, prints a full layer summary (name, type, input shapes, output shapes), and reports the total number of layers and parameters.
