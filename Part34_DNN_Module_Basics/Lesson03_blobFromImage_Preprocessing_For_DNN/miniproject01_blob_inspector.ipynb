# %% [markdown]
# # Mini Project 01 — Blob Inspector
#
# Build a preprocessing inspector tool that shows what an image looks like after blob creation for three popular model formats: ImageNet-normalized, COCO-normalized, and raw. Display the preprocessed tensor as an image.
