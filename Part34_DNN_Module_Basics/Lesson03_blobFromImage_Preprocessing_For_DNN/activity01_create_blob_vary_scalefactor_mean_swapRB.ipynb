# %% [markdown]
# # Activity 01 — Create a Blob: Vary scalefactor, mean, and swapRB
#
# Use cv2.dnn.blobFromImage with different scalefactor values (1/255.0, 1/127.5), mean subtraction values (ImageNet mean, zero), and swapRB settings. Visualize each blob as an image to understand preprocessing effects.
