# %% [markdown]
# # Activity 01 — Run Forward Pass, Measure Time, and Print Output Shape
#
# Load a model, preprocess an image into a blob, set it as input with net.setInput, run net.forward, measure the inference time, and print the output tensor shape.
