# %% [markdown]
# # Mini Project 01 — Model Inference Timer
#
# Build an inference benchmarking tool that runs the same model 100 times on the same input and reports mean, minimum, maximum, and standard deviation of inference time in milliseconds.
