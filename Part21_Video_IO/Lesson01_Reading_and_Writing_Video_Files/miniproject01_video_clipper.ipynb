# %% [markdown]
# # Mini Project 01 — Video Clipper
#
# Build a video clipping tool that takes a video file, a start time (seconds), and an end time (seconds) as inputs. Extract that time range and save it as a new video file with the same codec and FPS.
