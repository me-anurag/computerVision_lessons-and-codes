# %% [markdown]
# # Activity 01 — Read a Video, Print Properties, Save a Subclip
#
# Open a video with cv2.VideoCapture, print total frame count, FPS, and resolution. Then save only frames 100 to 300 as a new video file using cv2.VideoWriter.
