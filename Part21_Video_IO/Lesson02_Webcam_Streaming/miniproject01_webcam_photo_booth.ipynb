# %% [markdown]
# # Mini Project 01 — Webcam Photo Booth
#
# Build a webcam photo booth. Display the live feed with a countdown overlay. When the user presses spacebar, capture the frame and save it with a timestamp-based filename.
