# %% [markdown]
# # Activity 01 — Live Webcam: Display, Save Frame, Quit
#
# Open the webcam with cv2.VideoCapture(0). Display the live feed in a window. Press 's' to save the current frame as a .jpg file and press 'q' to quit the stream.
