# %% [markdown]
# # Activity 01 — Write Video at Half FPS for Slow Motion Effect
#
# Read a video and write it back using cv2.VideoWriter at half the original FPS. When played at normal speed, the output should appear in slow motion. Print the original and new FPS values.
