# %% [markdown]
# # Mini Project 01 — Video Info Tool
#
# Build a video information reporter. Given any video file, print a full report: resolution, FPS, total frame count, duration in seconds, and codec (fourcc) — formatted as a clean readable summary.
