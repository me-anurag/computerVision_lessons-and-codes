# %% [markdown]
# # Activity 01 — EAST Text Detection: Detect and Draw Text Regions
#
# Load the EAST text detection model. Run it on a natural scene image. Decode the output confidence map and geometry, apply NMS, and draw bounding boxes around detected text regions.
