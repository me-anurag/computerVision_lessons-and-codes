# %% [markdown]
# # Mini Project 01 — Street Sign Reader
#
# Build a street sign reading pipeline. Use EAST to detect text regions in a street scene image, crop each detected region, preprocess it, and run Tesseract to read the text. Display the detected text alongside each bounding box.
