# %% [markdown]
# # Activity 01 — Full OCR Pipeline: Preprocess → EAST Detect → Crop → Tesseract
#
# Build the complete end-to-end OCR pipeline: preprocess the input image, detect text regions with EAST, crop each region, apply per-region preprocessing, run Tesseract on each crop, and assemble the final text output.
