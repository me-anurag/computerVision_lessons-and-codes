# %% [markdown]
# # Mini Project 01 — Business Card Scanner
#
# Build a business card OCR tool. Take a business card photo, run the full OCR pipeline, and extract and display structured fields: person name, company, phone number, and email address.
