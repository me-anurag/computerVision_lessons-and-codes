# %% [markdown]
# # Activity 01 — Deskew, Binarize, Denoise and Compare OCR Accuracy
#
# Take a skewed and noisy document image. Apply deskewing, adaptive thresholding, and NLM denoising. Run Tesseract OCR before and after preprocessing and compare the text output quality.
