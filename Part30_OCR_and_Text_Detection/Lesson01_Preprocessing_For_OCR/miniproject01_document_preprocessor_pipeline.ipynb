# %% [markdown]
# # Mini Project 01 — Document Preprocessor Pipeline
#
# Build a complete OCR preprocessing pipeline: deskew the document, binarize with adaptive thresholding, remove noise with morphological ops, and output a clean image ready for OCR with maximum accuracy.
