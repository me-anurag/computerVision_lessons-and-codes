# %% [markdown]
# # Activity 01 — Tesseract on Clean vs Noisy Image and PSM Modes
#
# Run pytesseract.image_to_string on a clean text image and a noisy version. Compare output. Then try PSM modes 3 (auto), 6 (single block), 7 (single line), and 11 (sparse text) on different document types.
