# %% [markdown]
# # Mini Project 01 — Receipt Parser
#
# Build a receipt text extractor. Preprocess a receipt photo (deskew, binarize), run Tesseract to extract text, then parse key fields (total amount, date, store name) from the raw OCR output using string processing.
