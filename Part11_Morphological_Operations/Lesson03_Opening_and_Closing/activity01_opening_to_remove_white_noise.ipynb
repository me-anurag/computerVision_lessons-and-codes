# %% [markdown]
# # Activity 01 — Opening to Remove Small White Noise
#
# Add small white noise dots to a dark binary background. Apply morphological opening (erosion followed by dilation) to remove the noise while preserving larger foreground shapes.
