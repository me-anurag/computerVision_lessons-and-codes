# %% [markdown]
# # Activity 02 — Closing to Fill Small Holes Inside Objects
#
# Take a binary image with small holes inside objects. Apply morphological closing (dilation followed by erosion) to fill those holes without changing the outer boundary of the shapes.
