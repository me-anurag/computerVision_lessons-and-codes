# %% [markdown]
# # Mini Project 01 — Coin Segmenter
#
# Build a coin segmenter using morphological operations. Apply closing to fill coin regions completely, threshold to isolate them, then find and draw contours around each coin. Count the total number of coins detected.
