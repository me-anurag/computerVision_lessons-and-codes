# %% [markdown]
# # Mini Project 01 — Structuring Element Visualizer
#
# Build an interactive tool with trackbars for kernel shape (rect/ellipse/cross) and size. Apply the selected kernel to a binary image using erosion and dilation and show the kernel shape and morphological result side by side.
