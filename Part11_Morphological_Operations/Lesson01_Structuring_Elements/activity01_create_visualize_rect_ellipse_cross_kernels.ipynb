# %% [markdown]
# # Activity 01 — Create and Visualize Rect, Ellipse, and Cross Kernels
#
# Create structuring elements using cv2.getStructuringElement for MORPH_RECT, MORPH_ELLIPSE, and MORPH_CROSS at sizes 5x5, 11x11, and 21x21. Display each kernel as a binary image to visualize its shape.
