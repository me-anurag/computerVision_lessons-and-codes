# %% [markdown]
# # Mini Project 01 — Binary Image Noise Cleaner
#
# Build a noise removal tool for binary images. Use erosion with a small kernel to eliminate isolated noise pixels (small white specks) without destroying the main shapes. Compare before and after results.
