# %% [markdown]
# # Activity 01 — Erosion and Dilation on a Text Image
#
# Apply erosion and dilation to a binary text image with kernel sizes 3x3, 5x5, and 7x7. Observe how erosion thins characters and dilation thickens them. Display all results in a comparison grid.
