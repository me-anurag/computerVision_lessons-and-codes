# %% [markdown]
# # Activity 02 — Animate Kernel Size Progression
#
# Apply erosion and dilation with kernel sizes from 3 to 21 in steps of 2. Save each result as a frame and stitch them into a side-by-side animation or grid showing the progressive morphological effect.
