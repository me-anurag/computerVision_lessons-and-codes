# %% [markdown]
# # Mini Project 01 — License Plate Text Enhancer
#
# Build a license plate text enhancer using top hat morphology. Apply top hat to improve text contrast on uneven plate backgrounds, then binarize the result to produce clean, readable plate text.
