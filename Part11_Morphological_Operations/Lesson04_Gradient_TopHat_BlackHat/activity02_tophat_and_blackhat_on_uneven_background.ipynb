# %% [markdown]
# # Activity 02 — Top Hat and Black Hat on Uneven Background
#
# Apply morphological top hat (image minus opening) to detect bright features on a non-uniform background. Apply black hat (closing minus image) to detect dark features. Display and explain each result.
