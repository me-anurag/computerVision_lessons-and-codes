# %% [markdown]
# # Activity 01 — Morphological Gradient vs Canny Edge Detection
#
# Apply the morphological gradient (dilation minus erosion) to an image to detect object boundaries. Compare the result with Canny edge detection on the same image — observe differences in thickness and continuity.
