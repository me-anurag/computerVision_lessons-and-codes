# %% [markdown]
# # Activity 01 — Build a Gamma LUT and Apply with cv2.LUT
#
# Build a gamma correction lookup table for gamma values of 0.3, 0.5, 1.0, 1.5, and 2.5. Apply each using cv2.LUT and display all results to observe brightening (gamma < 1) and darkening (gamma > 1).
