# %% [markdown]
# # Mini Project 01 — Auto Gamma Corrector
#
# Build a tool that estimates the appropriate gamma value for an underexposed image based on its mean brightness, applies the correction using a LUT, and displays the before and after result.
