# %% [markdown]
# # Activity 02 — Custom Kernel Strength and Edge Artifacts
#
# Build sharpening kernels with increasing center weights (5, 9, 15) and apply each. Observe how stronger kernels increase sharpness but also introduce ringing artifacts at edges.
