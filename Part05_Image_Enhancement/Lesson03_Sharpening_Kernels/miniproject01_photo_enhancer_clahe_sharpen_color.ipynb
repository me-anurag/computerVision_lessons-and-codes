# %% [markdown]
# # Mini Project 01 — Photo Enhancer: CLAHE + Sharpening + Color Boost
#
# Build a photo enhancement pipeline that chains three steps: CLAHE for local contrast, sharpening for detail, and a slight saturation boost in HSV. Display original vs enhanced.
