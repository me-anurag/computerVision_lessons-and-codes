# %% [markdown]
# # Activity 01 — Apply Sharpening Kernel and Unsharp Mask
#
# Apply a standard sharpening kernel using cv2.filter2D, then implement unsharp masking (original + weight * (original - blurred)). Display and compare both sharpened results against the original.
