# %% [markdown]
# # Mini Project 01 — HDR Merger
#
# Build an HDR merging tool that takes 3 exposure images as input (dark, normal, bright), aligns them, merges using Mertens fusion, tone maps the result, and saves the final HDR image.
