# %% [markdown]
# # Activity 01 — Merge Exposures with Debevec and Mertens
#
# Load 3 or more bracketed exposure images of the same scene. Merge them using cv2.createMergeDebevec and cv2.createMergeMertens and display both HDR results.
