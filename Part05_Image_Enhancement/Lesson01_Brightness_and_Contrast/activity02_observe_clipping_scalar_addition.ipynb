# %% [markdown]
# # Activity 02 — Observe Clipping with Scalar Addition
#
# Add and subtract constant scalar values directly to a uint8 image using NumPy. Observe how values wrap around or clip compared to using cv2.add which handles saturation correctly.
