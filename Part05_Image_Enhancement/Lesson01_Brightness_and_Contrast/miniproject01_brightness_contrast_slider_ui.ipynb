# %% [markdown]
# # Mini Project 01 — Brightness/Contrast Slider UI
#
# Build a live trackbar UI with two sliders: one for contrast (alpha: 0.0 to 3.0) and one for brightness (beta: -100 to 100). Display the adjusted image in real time as sliders are moved.
