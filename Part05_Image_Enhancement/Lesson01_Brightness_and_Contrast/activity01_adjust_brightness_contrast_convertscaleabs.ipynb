# %% [markdown]
# # Activity 01 — Adjust Brightness and Contrast with convertScaleAbs
#
# Use cv2.convertScaleAbs(src, alpha, beta) to adjust contrast (alpha) and brightness (beta). Test alpha values (0.5, 1.0, 1.5, 2.0) and beta values (-50, 0, 50, 100) and display a grid of results.
