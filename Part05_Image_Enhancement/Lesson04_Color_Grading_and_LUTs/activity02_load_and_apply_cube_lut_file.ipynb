# %% [markdown]
# # Activity 02 — Load and Apply a .cube LUT File
#
# Parse a .cube format LUT file, build the corresponding lookup table, and apply it to an image using trilinear interpolation or a simplified 1D approximation. Display the color-graded result.
