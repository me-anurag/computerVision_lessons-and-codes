# %% [markdown]
# # Mini Project 01 — Cinematic Filter Pack
#
# Build 3 different cinematic color grade presets (warm golden hour, cool teal-orange, faded vintage) using LUTs or channel curve adjustments. Apply all 3 to the same photo and display them in a grid.
