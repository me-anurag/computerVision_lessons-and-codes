# %% [markdown]
# # Activity 01 — Apply Warm and Cool Color LUTs
#
# Build a warm LUT (boost red and reduce blue) and a cool LUT (boost blue and reduce red) using NumPy arrays. Apply each with cv2.LUT and display the original, warm, and cool versions side by side.
