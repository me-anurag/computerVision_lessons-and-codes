# %% [markdown]
# # Activity 02 — Create Blank Images: Black, White, Red
#
# Use NumPy to create a blank black image (all zeros), a white image (all 255), and a red image (only the blue channel set), then display all three using cv2.imshow.
