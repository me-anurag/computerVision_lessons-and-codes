# %% [markdown]
# # Mini Project 01 — Environment Checker
#
# Build a script that prints a full environment report: Python version, OpenCV version, NumPy version, and whether CUDA is available — formatted as a clean readable summary.
