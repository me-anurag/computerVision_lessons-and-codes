# %% [markdown]
# # Activity 01 — Install OpenCV and Print Version
#
# Install OpenCV and NumPy, print the OpenCV version, and inspect the full build information using cv2.getBuildInformation() to understand which modules and backends are available.
