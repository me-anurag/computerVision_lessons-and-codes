# %% [markdown]
# # Activity 02 — Display Image for Exactly 3 Seconds
#
# Display an image using cv2.imshow and use cv2.waitKey(3000) to close it automatically after exactly 3 seconds without any key press.
