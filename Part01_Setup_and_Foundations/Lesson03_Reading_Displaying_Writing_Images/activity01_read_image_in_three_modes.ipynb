# %% [markdown]
# # Activity 01 — Read Image in Three Modes
#
# Read the same image using cv2.IMREAD_COLOR, cv2.IMREAD_GRAYSCALE, and cv2.IMREAD_UNCHANGED. Print the shape of each result and explain the difference.
