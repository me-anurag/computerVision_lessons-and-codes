# %% [markdown]
# # Mini Project 01 — Batch Image Converter
#
# Build a script that reads all .jpg files in a given folder and saves each one as a .png file in an output folder, preserving the filename.
