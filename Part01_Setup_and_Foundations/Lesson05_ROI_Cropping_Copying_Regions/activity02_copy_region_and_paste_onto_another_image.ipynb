# %% [markdown]
# # Activity 02 — Copy Region and Paste onto Another Image
#
# Copy a rectangular region from one image and paste it onto a specific location on a second image using NumPy array assignment.
