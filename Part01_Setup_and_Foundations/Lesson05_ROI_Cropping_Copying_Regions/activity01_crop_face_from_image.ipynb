# %% [markdown]
# # Activity 01 — Crop a Face from an Image
#
# Manually define pixel coordinates of a face region in an image and use NumPy slicing to crop it out, then display both the original and the cropped region.
