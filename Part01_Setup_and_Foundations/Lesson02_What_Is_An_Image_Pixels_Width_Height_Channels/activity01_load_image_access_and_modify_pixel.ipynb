# %% [markdown]
# # Activity 01 — Load Image, Access and Modify a Pixel
#
# Load a color image, print its shape, access the pixel value at position (0,0), change it to red (0,0,255 in BGR), and display the result.
