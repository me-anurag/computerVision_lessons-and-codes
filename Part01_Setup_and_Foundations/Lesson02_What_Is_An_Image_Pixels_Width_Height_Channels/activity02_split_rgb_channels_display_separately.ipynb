# %% [markdown]
# # Activity 02 — Split RGB Channels and Display Separately
#
# Split a color image into its B, G, R channels using cv2.split, display each channel as a grayscale image, and observe what each channel encodes.
