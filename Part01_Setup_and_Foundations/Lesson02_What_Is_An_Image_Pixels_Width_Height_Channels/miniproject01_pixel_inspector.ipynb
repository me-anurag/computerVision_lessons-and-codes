# %% [markdown]
# # Mini Project 01 — Pixel Inspector
#
# Build an interactive tool using mouse callbacks: when the user clicks anywhere on the image, print the BGR value, RGB value, and HSV value of that exact pixel to the console.
