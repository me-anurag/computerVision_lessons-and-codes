# %% [markdown]
# # Mini Project 01 — Image Metadata Reporter
#
# Given a folder path, scan all images inside and print a summary table showing: filename, resolution (WxH), number of channels, dtype, and file size in KB.
