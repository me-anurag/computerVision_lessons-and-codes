# %% [markdown]
# # Activity 02 — dtype Behavior: uint8 vs float32
#
# Create images with uint8 and float32 dtypes, add values that exceed 255, and observe how each dtype handles overflow and clipping differently.
