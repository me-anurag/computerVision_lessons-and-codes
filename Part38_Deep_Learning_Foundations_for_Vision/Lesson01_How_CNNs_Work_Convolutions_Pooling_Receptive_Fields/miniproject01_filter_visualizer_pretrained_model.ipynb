# %% [markdown]
# # Mini Project 01 — Filter Visualizer for Pretrained CNN
#
# Build a feature map visualizer. Load a pretrained model (e.g. VGG16), pass an image through it, and visualize the activation maps of the first convolutional layer to see what each filter responds to.
