# %% [markdown]
# # Activity 01 — Apply a Single Filter Manually and Verify vs nn.Conv2d
#
# Implement a 2D convolution manually using NumPy (sliding window). Compare the output to PyTorch nn.Conv2d with the same filter weights. Verify they match and observe how the filter transforms the feature map.
