# %% [markdown]
# # Activity 01 — Compute Cross Entropy, Focal Loss, and Dice Loss on Sample Predictions
#
# Implement cross entropy, focal loss, and dice loss from scratch or using libraries. Compute all three on the same sample predictions. Print and compare the loss values for easy vs hard examples.
