# %% [markdown]
# # Mini Project 01 — Loss Function Comparator on Imbalanced Dataset
#
# Train two identical CNN models on an imbalanced dataset: one with cross entropy loss and one with focal loss. Compare final accuracy per class, confusion matrices, and overall performance to show how focal loss handles imbalance better.
