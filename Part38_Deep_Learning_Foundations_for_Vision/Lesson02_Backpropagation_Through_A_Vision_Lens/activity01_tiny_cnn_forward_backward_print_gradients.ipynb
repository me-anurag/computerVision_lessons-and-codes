# %% [markdown]
# # Activity 01 — Tiny CNN: Forward Pass, Backward Pass, Print Gradients
#
# Build a minimal 2-layer CNN in PyTorch. Run a forward pass on a single image, compute a loss, run backward, and print the gradients for each layer's weights to understand how gradients flow through a CNN.
