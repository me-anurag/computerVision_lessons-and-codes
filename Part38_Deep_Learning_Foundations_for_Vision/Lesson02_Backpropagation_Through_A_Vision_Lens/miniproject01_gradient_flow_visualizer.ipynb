# %% [markdown]
# # Mini Project 01 — Gradient Flow Visualizer
#
# Build a gradient flow tool using PyTorch hooks. Register backward hooks on each layer of a CNN, capture gradient magnitudes during a backward pass, and plot a bar chart showing gradient strength per layer.
