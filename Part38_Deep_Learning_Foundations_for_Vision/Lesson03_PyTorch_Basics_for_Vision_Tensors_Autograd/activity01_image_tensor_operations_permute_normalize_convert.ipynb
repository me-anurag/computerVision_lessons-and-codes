# %% [markdown]
# # Activity 01 — Image Tensor Operations: Permute, Normalize, Convert
#
# Load an image with OpenCV (HxWxC, BGR, uint8). Convert to a PyTorch tensor (CxHxW, RGB, float32). Apply ImageNet normalization. Convert back to NumPy and display. Print shape and dtype at each step.
