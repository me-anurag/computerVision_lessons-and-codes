# %% [markdown]
# # Mini Project 01 — Image Tensor Inspector
#
# Build a tensor inspection tool. Load any image, convert to a normalized PyTorch tensor, and print a full report: shape, dtype, min, max, mean, std — then display the image with these stats shown as a text overlay.
