# %% [markdown]
# # Mini Project 01 — Full Training Loop with Model Checkpointing
#
# Build a complete training loop that saves the best model checkpoint when validation accuracy improves. Include early stopping after N epochs without improvement. Demonstrate resuming training from a saved checkpoint.
