# %% [markdown]
# # Activity 01 — Train a CNN for 5 Epochs and Plot Loss/Accuracy Curves
#
# Define a simple CNN architecture, train it on CIFAR-10 for 5 epochs with train/val split. Record train loss, val loss, train accuracy, and val accuracy per epoch. Plot all 4 curves on a single figure.
