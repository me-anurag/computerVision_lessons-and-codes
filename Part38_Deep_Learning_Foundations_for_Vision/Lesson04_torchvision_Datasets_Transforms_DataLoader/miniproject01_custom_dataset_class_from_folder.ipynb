# %% [markdown]
# # Mini Project 01 — Custom Dataset Class from Image Folder
#
# Build a custom PyTorch Dataset class that loads images from a folder structured as class subfolders. Wrap it in a DataLoader, apply transforms, iterate one batch, and display a sample grid with class names.
