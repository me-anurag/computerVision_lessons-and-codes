# %% [markdown]
# # Activity 01 — CIFAR-10 DataLoader: Apply Transforms and Visualize a Batch
#
# Load CIFAR-10 using torchvision.datasets.CIFAR10, apply a transform pipeline (resize, normalize, random flip), create a DataLoader, iterate one batch, and display the 32 images in a 4x8 grid with class labels.
