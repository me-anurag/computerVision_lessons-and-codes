# %% [markdown]
# # Activity 01 — Set Reference Length in Pixels and Measure Objects
#
# Place a known-size reference object (e.g. a credit card) next to objects to measure. Compute the pixels-per-cm ratio from the reference, then measure the width and height of other objects in the same image.
