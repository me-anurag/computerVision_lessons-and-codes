# %% [markdown]
# # Mini Project 01 — Object Size Measurer
#
# Build a measurement tool that uses a reference object (credit card or ruler) in the image to establish a pixel-to-cm scale. Detect all objects using contours, compute their real-world dimensions, and display the measurements.
