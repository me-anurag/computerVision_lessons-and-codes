# %% [markdown]
# # Mini Project 01 — PCB Defect Detector
#
# Build a PCB inspection tool. Compare a reference PCB image against a test PCB image, detect regions with missing or misplaced components by thresholding the difference image, and generate a defect report with locations.
