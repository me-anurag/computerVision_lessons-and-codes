# %% [markdown]
# # Activity 01 — Compare Reference vs Test Image and Highlight Differences
#
# Load a reference (defect-free) image and a test image. Align them, compute their absolute difference, threshold it, and draw bounding boxes around regions that differ significantly — potential defects.
