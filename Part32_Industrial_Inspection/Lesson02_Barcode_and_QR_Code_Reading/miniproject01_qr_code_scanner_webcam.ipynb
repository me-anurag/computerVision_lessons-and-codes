# %% [markdown]
# # Mini Project 01 — Live QR Code Scanner on Webcam
#
# Build a live QR code scanner using the webcam. Detect and decode QR codes in each frame, display the decoded text as an overlay, and automatically open the URL in a browser when a valid URL is detected.
