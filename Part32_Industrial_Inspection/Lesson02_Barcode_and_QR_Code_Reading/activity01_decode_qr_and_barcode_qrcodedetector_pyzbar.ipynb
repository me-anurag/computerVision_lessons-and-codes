# %% [markdown]
# # Activity 01 — Decode QR Codes and Barcodes Using QRCodeDetector and pyzbar
#
# Use cv2.QRCodeDetector to detect and decode a QR code from an image. Then use the pyzbar library to decode both QR codes and barcodes. Print the decoded data and draw the detection polygon.
