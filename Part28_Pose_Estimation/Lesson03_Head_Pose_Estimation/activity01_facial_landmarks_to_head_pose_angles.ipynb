# %% [markdown]
# # Activity 01 — Estimate Head Pose Angles from Facial Landmarks
#
# Detect facial landmarks using dlib or MediaPipe. Match key landmarks (nose tip, chin, eye corners, mouth corners) to a generic 3D face model. Run solvePnP and compute pitch, yaw, and roll angles.
