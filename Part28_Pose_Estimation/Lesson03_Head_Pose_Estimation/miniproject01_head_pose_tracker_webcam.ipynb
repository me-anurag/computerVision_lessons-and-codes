# %% [markdown]
# # Mini Project 01 — Real-Time Head Pose Tracker on Webcam
#
# Build a live head pose estimation tool. Detect facial landmarks on each webcam frame, run solvePnP, draw the 3D axes on the face, and display the current pitch, yaw, and roll angles as text overlay.
