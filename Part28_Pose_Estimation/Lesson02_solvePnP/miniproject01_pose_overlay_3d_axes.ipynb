# %% [markdown]
# # Mini Project 01 — Pose Overlay: Draw 3D Axes on a Known Object
#
# Build a pose overlay tool. Given a known planar object, detect its corners, run solvePnP, and draw 3D coordinate axes on the object surface to visualize its orientation in 3D space.
