# %% [markdown]
# # Activity 01 — solvePnP: Compute Pose from 3D-2D Point Correspondences
#
# Define known 3D object points (e.g. corners of a box) and their corresponding 2D image locations. Use cv2.solvePnP to estimate the rotation and translation vectors. Print the estimated pose.
