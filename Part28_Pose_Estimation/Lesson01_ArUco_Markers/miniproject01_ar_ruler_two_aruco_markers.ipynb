# %% [markdown]
# # Mini Project 01 — AR Ruler: Measure Distance Between Two ArUco Markers
#
# Build an AR ruler tool. Place two ArUco markers in a scene, estimate the pose of each, compute the 3D distance between their centers using their translation vectors, and display the real-world distance in cm as an overlay.
