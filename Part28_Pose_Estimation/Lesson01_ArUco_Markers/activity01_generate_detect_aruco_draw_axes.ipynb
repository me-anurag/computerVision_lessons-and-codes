# %% [markdown]
# # Activity 01 — Generate ArUco Markers, Detect, and Draw 3D Axes
#
# Generate an ArUco marker using cv2.aruco. Print it and capture it with a camera (or use a static image). Detect the marker, estimate its pose, and draw 3D coordinate axes on it using cv2.drawFrameAxes.
