# %% [markdown]
# # Activity 01 — Simulate Motion Blur and Apply Wiener Filter
#
# Simulate horizontal motion blur by convolving an image with a motion blur kernel. Then apply a Wiener filter in the frequency domain to restore the sharpness and compare with the original.
