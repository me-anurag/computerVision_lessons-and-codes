# %% [markdown]
# # Mini Project 01 — Motion Blur Restorer
#
# Build a motion blur restoration tool. Estimate the blur direction and length from the image's frequency spectrum spike pattern, construct the corresponding deconvolution filter, and apply it to recover a sharper image.
