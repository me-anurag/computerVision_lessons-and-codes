# %% [markdown]
# # Activity 01 — Compare NLM, Gaussian, and Median Denoising with PSNR
#
# Add Gaussian noise to a clean image. Apply NLM denoising, Gaussian blur, and median blur. Compute PSNR for each compared to the original clean image and display all results with their PSNR scores.
