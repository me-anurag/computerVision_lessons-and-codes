# %% [markdown]
# # Activity 02 — Tune the h (Filter Strength) Parameter in NLM
#
# Apply cv2.fastNlMeansDenoisingColored with h values of 3, 7, 15, and 25. Display all results side by side and observe the tradeoff between noise removal and loss of fine detail.
