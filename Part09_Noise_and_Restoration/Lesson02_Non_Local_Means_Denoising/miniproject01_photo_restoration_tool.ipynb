# %% [markdown]
# # Mini Project 01 — Photo Restoration Tool
#
# Build a photo restoration tool for noisy old photos. Apply NLM denoising with tuned parameters, followed by slight sharpening to recover lost detail. Display and save the restored version.
