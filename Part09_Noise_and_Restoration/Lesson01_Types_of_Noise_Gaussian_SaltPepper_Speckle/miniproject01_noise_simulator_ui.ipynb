# %% [markdown]
# # Mini Project 01 — Noise Simulator UI
#
# Build an interactive noise simulator with trackbar sliders for noise type selection and intensity. Show the noisy preview in real time as sliders are adjusted.
