# %% [markdown]
# # Activity 01 — Add Gaussian, Salt-and-Pepper, and Speckle Noise
#
# Programmatically add three types of noise to a clean image: Gaussian noise (using np.random.normal), salt-and-pepper noise (random pixel flipping), and speckle noise (multiplicative noise). Display all four versions.
