# %% [markdown]
# # Mini Project 01 — Watermark Remover
#
# Build an interactive watermark removal tool. The user draws a mask over the watermark region using mouse callbacks, then the tool applies inpainting to fill the region and saves the clean result.
