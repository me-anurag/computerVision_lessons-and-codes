# %% [markdown]
# # Activity 01 — Inpaint a Watermark: TELEA vs Navier-Stokes
#
# Manually draw a binary mask over a watermark or text overlay on an image. Apply both cv2.INPAINT_TELEA and cv2.INPAINT_NS. Display both results side by side and compare restoration quality.
