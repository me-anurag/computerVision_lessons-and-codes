# %% [markdown]
# # Activity 01 — Multi-Scale Template Matching: Find Best Scale
#
# Scale the scene image at multiple levels (50% to 150% in steps). Run template matching at each scale. Track the best match score across all scales, rescale the result coordinates, and draw the final bounding box.
