# %% [markdown]
# # Mini Project 01 — Multi-Scale Object Finder
#
# Build a scale-invariant template matching tool that finds a template in a scene regardless of size difference. Search across multiple scales, find the best match, and draw the detected region with its matched scale ratio.
