# %% [markdown]
# # Mini Project 01 — Logo Finder
#
# Build a logo detection tool that takes a template logo and searches for it in a document scan or larger image. Draw a bounding box around the best match location and display the match confidence score.
