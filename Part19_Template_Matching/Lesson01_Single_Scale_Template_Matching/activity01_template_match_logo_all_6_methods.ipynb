# %% [markdown]
# # Activity 01 — Template Match a Logo Using All 6 Methods
#
# Apply cv2.matchTemplate with all 6 methods (TM_CCOEFF, TM_CCOEFF_NORMED, TM_CCORR, TM_CCORR_NORMED, TM_SQDIFF, TM_SQDIFF_NORMED) on the same image-template pair. Display the result maps and bounding boxes.
