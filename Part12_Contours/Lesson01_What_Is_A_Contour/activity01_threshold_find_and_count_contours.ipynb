# %% [markdown]
# # Activity 01 — Threshold an Image, Find and Count Contours
#
# Threshold a simple binary shape image, apply cv2.findContours, print the total number of contours found, and draw all of them on a copy of the original image.
