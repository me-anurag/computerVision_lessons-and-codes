# %% [markdown]
# # Mini Project 01 — Shape Counter
#
# Build a shape counting tool that takes a binary or high-contrast image, finds all distinct contours, filters out noise by minimum area, and prints and displays the count of detected objects.
