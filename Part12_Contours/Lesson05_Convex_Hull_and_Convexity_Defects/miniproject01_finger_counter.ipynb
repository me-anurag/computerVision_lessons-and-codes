# %% [markdown]
# # Mini Project 01 — Finger Counter
#
# Build a finger counting tool using convexity defects. Detect the hand contour, compute defects, filter by angle and depth to count the valleys between fingers, and display the finger count as text overlay on the image.
