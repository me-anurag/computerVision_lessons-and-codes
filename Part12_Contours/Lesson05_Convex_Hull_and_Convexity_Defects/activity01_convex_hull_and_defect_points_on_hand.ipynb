# %% [markdown]
# # Activity 01 — Convex Hull and Defect Points on a Hand Silhouette
#
# Find the contour of a hand silhouette, compute its convex hull using cv2.convexHull, and find convexity defects using cv2.convexityDefects. Draw the hull, the contour, and the defect points (fingertip gaps).
