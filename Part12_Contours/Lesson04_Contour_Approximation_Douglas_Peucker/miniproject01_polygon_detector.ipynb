# %% [markdown]
# # Mini Project 01 — Polygon Detector
#
# Build a polygon shape detector. Use contour approximation to count the number of vertices for each detected shape and classify it as triangle (3), rectangle (4), pentagon (5), hexagon (6), or circle (>6).
