# %% [markdown]
# # Activity 02 — approxPolyDP with Increasing Epsilon Values
#
# Apply cv2.approxPolyDP to a contour with epsilon values of 1%, 2%, 5%, and 10% of the arc length. Draw the approximated polygon at each level and observe how the shape simplifies progressively.
