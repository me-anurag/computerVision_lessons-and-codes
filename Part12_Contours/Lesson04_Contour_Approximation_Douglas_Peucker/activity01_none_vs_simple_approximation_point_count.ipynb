# %% [markdown]
# # Activity 01 — CHAIN_APPROX_NONE vs CHAIN_APPROX_SIMPLE Point Count
#
# Find contours using CHAIN_APPROX_NONE and CHAIN_APPROX_SIMPLE on the same image. Print the number of points in each contour for both methods and compute the memory savings.
