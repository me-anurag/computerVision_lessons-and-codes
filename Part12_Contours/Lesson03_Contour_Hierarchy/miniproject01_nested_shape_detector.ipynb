# %% [markdown]
# # Mini Project 01 — Nested Shape Detector
#
# Build a tool that uses RETR_TREE hierarchy to identify parent-child contour relationships. Highlight outer shapes in one color and inner nested shapes in another to visually show which shapes contain other shapes.
