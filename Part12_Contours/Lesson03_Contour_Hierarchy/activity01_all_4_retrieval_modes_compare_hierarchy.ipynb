# %% [markdown]
# # Activity 01 — Compare All 4 Contour Retrieval Modes
#
# Apply cv2.findContours with RETR_EXTERNAL, RETR_LIST, RETR_CCOMP, and RETR_TREE on the same image. Print the hierarchy arrays and number of contours found for each mode and explain the differences.
