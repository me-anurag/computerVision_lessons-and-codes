# %% [markdown]
# # Mini Project 01 — Object Highlighter
#
# Build a tool that detects all objects in a binary image using contours and draws a uniquely colored bounding box around each one, labeling them Object 1, Object 2, etc.
