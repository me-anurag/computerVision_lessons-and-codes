# %% [markdown]
# # Activity 01 — Draw All Contours, Largest Only, and Area-Filtered
#
# Find all contours in an image. Draw all of them in green, then separately draw only the largest contour in red, and finally draw only contours with area above a threshold in blue. Display all three results.
