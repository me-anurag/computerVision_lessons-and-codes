# %% [markdown]
# # Mini Project 01 — Haze and Fog Removal Enhancer
#
# Build a haze removal tool using dark channel prior dehazing. Take outdoor foggy images as input, apply the dehazing pipeline, and display the before and after results side by side.
