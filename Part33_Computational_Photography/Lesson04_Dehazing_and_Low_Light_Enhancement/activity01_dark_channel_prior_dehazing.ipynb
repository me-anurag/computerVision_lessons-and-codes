# %% [markdown]
# # Activity 01 — Dark Channel Prior Dehazing on a Foggy Image
#
# Implement the dark channel prior algorithm: compute the dark channel map, estimate atmospheric light, compute the transmission map, and recover the dehazed image. Apply to an outdoor foggy photo.
