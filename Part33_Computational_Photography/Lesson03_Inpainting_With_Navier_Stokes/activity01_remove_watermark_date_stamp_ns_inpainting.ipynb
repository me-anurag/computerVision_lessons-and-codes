# %% [markdown]
# # Activity 01 — Remove Watermark or Date Stamp Using NS Inpainting
#
# Create or find an image with a visible watermark or date stamp. Manually create a binary mask covering the unwanted text. Apply cv2.inpaint with INPAINT_NS and display the cleaned result.
