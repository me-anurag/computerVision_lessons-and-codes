# %% [markdown]
# # Mini Project 01 — Old Photo Restorer
#
# Build a photo restoration tool for scanned old photos with scratches and stains. Let the user draw a mask over damaged regions, apply Navier-Stokes inpainting to fill them, and save the restored photo.
