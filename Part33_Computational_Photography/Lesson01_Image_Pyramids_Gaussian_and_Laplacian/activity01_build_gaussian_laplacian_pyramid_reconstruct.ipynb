# %% [markdown]
# # Activity 01 — Build Gaussian and Laplacian Pyramid, Then Reconstruct
#
# Build a 5-level Gaussian pyramid using cv2.pyrDown. Compute the Laplacian pyramid by subtracting each level from the upsampled level above. Reconstruct the original image from the Laplacian pyramid and verify accuracy.
