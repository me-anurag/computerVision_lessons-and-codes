# %% [markdown]
# # Mini Project 01 — Multi-Resolution Image Blender
#
# Build a seamless image blending tool using Laplacian pyramid blending. Blend two images along a vertical seam using their Laplacian pyramids and a Gaussian-blurred mask. Compare with direct alpha blending.
