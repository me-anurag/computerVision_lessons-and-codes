# %% [markdown]
# # Activity 01 — SeamlessClone vs Direct Copy-Paste
#
# Cut an object from one image and paste it onto another background using direct copy-paste. Then use cv2.seamlessClone with NORMAL_CLONE mode. Display both results and observe the seamless blending difference.
