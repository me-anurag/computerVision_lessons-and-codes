# %% [markdown]
# # Mini Project 01 — Face Transplant Tool
#
# Build a face cloning tool using cv2.seamlessClone. Detect and extract a face region from one portrait photo and seamlessly blend it into the correct position on another face photo using Poisson blending.
