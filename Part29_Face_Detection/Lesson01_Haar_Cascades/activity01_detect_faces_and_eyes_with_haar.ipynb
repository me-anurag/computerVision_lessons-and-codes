# %% [markdown]
# # Activity 01 — Detect Faces and Eyes Using Haar Cascades
#
# Load a face image and apply the Haar face cascade (haarcascade_frontalface_default) to detect faces. For each detected face ROI, apply the eye cascade to detect eyes. Draw green boxes for faces and blue for eyes.
