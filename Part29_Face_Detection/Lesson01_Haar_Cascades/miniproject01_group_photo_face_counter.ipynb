# %% [markdown]
# # Mini Project 01 — Group Photo Face Counter
#
# Build a group photo face counter using Haar cascades. Load a group photo, detect all faces, draw a numbered box around each, and display the total face count as a text overlay on the image.
