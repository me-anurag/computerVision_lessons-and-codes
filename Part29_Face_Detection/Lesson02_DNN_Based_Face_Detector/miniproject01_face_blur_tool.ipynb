# %% [markdown]
# # Mini Project 01 — Face Blur Tool for Privacy
#
# Build a face privacy tool using the DNN face detector. Detect all faces in an image or video frame and apply Gaussian blur to each detected face region to anonymize them.
