# %% [markdown]
# # Activity 01 — Haar vs DNN Face Detector on Difficult Cases
#
# Compare Haar and DNN face detectors on challenging images: partial faces, side-view faces, and low-light conditions. Count detections and compare false positives/negatives.
