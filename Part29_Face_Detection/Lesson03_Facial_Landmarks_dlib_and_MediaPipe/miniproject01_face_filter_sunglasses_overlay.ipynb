# %% [markdown]
# # Mini Project 01 — Face Filter: Sunglasses Overlay
#
# Build a fun face filter using facial landmarks. Detect the eye landmark positions, scale and align a sunglasses image to fit across both eyes, and overlay it with proper alpha blending on a face photo or webcam feed.
