# %% [markdown]
# # Activity 01 — Detect 68 Facial Landmarks and Draw Numbered Points
#
# Use dlib's 68-point shape predictor to detect facial landmarks. Draw each landmark as a dot and label it with its index number. Identify the groups: jawline (1-17), eyebrows (18-27), nose (28-36), eyes (37-48), mouth (49-68).
